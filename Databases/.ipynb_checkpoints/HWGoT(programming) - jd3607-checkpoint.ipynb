# %% [markdown]
# <style  type="text/css">
# cool {
#   width: 100px;
#   height: 100px;
#   background-color: red;
#   position: relative;
#   -webkit-animation-name: example; /* Safari 4.0 - 8.0 */
#   -webkit-animation-duration: 4s; /* Safari 4.0 - 8.0 */
#   -webkit-animation-iteration-count: infinite; /* Safari 4.0 - 8.0 */
#   animation-name: example;
#   animation-duration: 4s;
#   animation-iteration-count: infinite;
# }
#
# /* Safari 4.0 - 8.0 */
# @-webkit-keyframes example {
#   0%   {background-color:red; left:0px; top:0px;}
#   25%  {background-color:yellow; left:200px; top:0px;}
#   50%  {background-color:blue; left:200px; top:200px;}
#   75%  {background-color:green; left:0px; top:200px;}
#   100% {background-color:red; left:0px; top:0px;}
# }
#
# /* Standard syntax */
# @keyframes example {
#   0%   {background-color:red; left:0px; top:0px;}
#   25%  {background-color:yellow; left:200px; top:0px;}
#   50%  {background-color:blue; left:200px; top:200px;}
#   75%  {background-color:green; left:0px; top:200px;}
#   100% {background-color:red; left:0px; top:0px;}
# }
# </style>
#
# <b><center>
# <span style="font-size: 24pt; line-height: 1.2">
# COMS W4111: Introduction to Databases<br>
# Spring 2020, Sections 002, H02, V02
# </span>
# </center></b>
# </span><br>
# <p>
# <i><center>
# <span style="font-size: 20pt; line-height: 1.2">
# Programming Project Notebook<br>
# </span>
# </center></i>

# %% [markdown]
# # Introduction
#
# - This notebook defines HW1, Part C for both the programming and no-programming tracks.
#
#
# - Submission instructions:
#     - Both no programming and programming tracks submit a zip file containing all of the files in the HW project directory that you clone (see below).
#     - Much of your work is completing sections of this notebook, but you MUST edit the copy in the project directory.
#     - If you reference or create any files, please create in the project directory.
#     - The name of your zip file MUST be ```uni_W4111_s20_hw1c,```  replace ```uni``` with you UNI. My submission would be ```dff9_W4111_s20_hw1c.```
#     - The homework is due on 23-February-2020 at 11:59 PM. You MAY use late days.
#
# - We will use the pinned [Piazza post](https://piazza.com/class/k5grpo7gmn71pj?cid=301) to clarify the homework and answer questions.
#
#
# # Common Setup
#
# Both tracks should:
# - MySQL: Install
#     - [MySQL Server Community Edition](https://dev.mysql.com/doc/mysql-installation-excerpt/8.0/en/)
#     - [MySQL Workbench](https://dev.mysql.com/doc/workbench/en/)
#     - In addition to the official links, there are many operating specific tutorials.
#
#
# - Create a [Lucidchart educational account.](https://lucidchart.zendesk.com/hc/en-us/articles/207324096-Get-Started-with-an-Educational-Account)
#
#
# - Project template:
#     - If you do not have ```Git``` on your computer, please install it.
#     - Homework 1 setup instructions recommended that you create a folder ```/IntroToDB``` on your desktop.
#     - Under this directory, create a folder ```HW1C.```
#     - Open terminal shell or Git enabled command prompt.
#     - CD to the directory you created and enter ```git clone https://github.com/donald-f-ferguson/GoTHW```
#     - This will create the project template for you.
#
# | <img src="./got_hw_project.png"> |
# | :---: |
# | __HW1C Project Template__ |

# %% [markdown]
# - Run the following cells. Your answers WILL BE different than the sample output.

# %%
import sys
import os
import platform
import psutil

print("="*40, "Path Information", "="*40)
print("Path = ", os.getcwd())

print("="*40, "System Information", "="*40)
uname = platform.uname()
print(f"System: {uname.system}")
print(f"Node Name: {uname.node}")
print(f"Release: {uname.release}")
print(f"Version: {uname.version}")
print(f"Machine: {uname.machine}")
print(f"Processor: {uname.processor}")

print("="*40, "Network Information", "="*40)

import socket    
hostname = socket.gethostname()    
IPAddr = socket.gethostbyname(hostname)    
print("Your Computer Name is:" + hostname)    
print("Your Computer IP Address is:" + IPAddr) 

import uuid
print ("Your MAC address is:", hex(uuid.getnode()))
# Out:
# ======================================== Path Information ========================================
# Path =  C:\Users\59482\Desktop\IntroToDB\HW1C\GoTHW
# ======================================== System Information ========================================
# System: Windows
# Node Name: LAPTOP-VJIRBLR4
# Release: 10
# Version: 10.0.17763
# Machine: AMD64
# Processor: Intel64 Family 6 Model 158 Stepping 10, GenuineIntel
# ======================================== Network Information ========================================
# Your Computer Name is:LAPTOP-VJIRBLR4
# Your Computer IP Address is:192.168.0.200
# Your MAC address is: 0x4ea56df6528

# %% [markdown]
# # Programming
#
# ## Overview
#
# - Ensuring that programming track students build core skills is essential. Programming track assignments will contain a subset of the broader, more complete tasks assigned in the No programming assignments. So, there is a common core section to the programming track homework.
#
#
# - Additionally, the programming track will have tasks that reinforce skills necessary for programming and databases.
#
#
# ## Common Core
#
# ### Tasks
#
# - Schema and DML: For the following tables, perform the data import, data cleanup and schema improvement takes for the following tables:
# 1. ```characters```
# 2. ```scenes```
# 3. ```scenes_characters```
#
#
# - Views
#     1. Implement the view in 3.5.3, "Character Interactions."
#     2. Define, explain and implement a view of you choosing.
#
# ### Answers
#
# <u>Data Import and Cleanup</u>

# %% [markdown]
# - Connect to database

# %%
import pymysql
# %load_ext sql
# %sql mysql+pymysql://root:Djxwxydy4016739@localhost/W4111GoTSolution
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# 'Connected: root@W4111GoTSolution'

# %% [markdown]
# - Characters
#    - Setting types to columns

# %%
# %%sql
# ALTER TABLE `w4111gotsolution`.`characters`
# CHANGE COLUMN `characterName` `characterName` VARCHAR(64) NULL DEFAULT NULL ,
# CHANGE COLUMN `characterLink` `characterLink` VARCHAR(128) NULL DEFAULT NULL ,
# CHANGE COLUMN `actorName` `actorName` VARCHAR(128) NULL DEFAULT NULL ,
# CHANGE COLUMN `actorLink` `actorLink` VARCHAR(128) NULL DEFAULT NULL ,
# CHANGE COLUMN `character_id` `character_id` VARCHAR(16) NULL DEFAULT NULL ,
# CHANGE COLUMN `characterImageThumb` `characterImageThumb` VARCHAR(512) NULL DEFAULT NULL ,
# CHANGE COLUMN `characterImageFull` `characterImageFull` VARCHAR(512) NULL DEFAULT NULL ,
# CHANGE COLUMN `nickname` `nickname` VARCHAR(64) NULL DEFAULT NULL ;
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 389 rows affected.
# []

# %%
# %sql describe characters
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 11 rows affected.
# [('id', 'int', 'YES', '', None, ''),
#  ('characterName', 'varchar(64)', 'YES', '', None, ''),
#  ('characterLink', 'varchar(128)', 'YES', '', None, ''),
#  ('actorName', 'varchar(128)', 'YES', '', None, ''),
#  ('actorLink', 'varchar(128)', 'YES', '', None, ''),
#  ('character_id', 'varchar(16)', 'YES', '', None, ''),
#  ('royal', 'text', 'YES', '', None, ''),
#  ('characterImageThumb', 'varchar(512)', 'YES', '', None, ''),
#  ('characterImageFull', 'varchar(512)', 'YES', '', None, ''),
#  ('nickname', 'varchar(64)', 'YES', '', None, ''),
#  ('kingsguard', 'text', 'YES', '', None, '')]

# %% [markdown]
# - Characters
#    - NULL OR NOT NULL ?
#    - Primary key
#    - Unique

# %%
# %%sql
# ALTER TABLE `w4111gotsolution`.`characters`
# CHANGE COLUMN `id` `id` INT NOT NULL ,
# CHANGE COLUMN `characterName` `characterName` VARCHAR(64) NOT NULL ,
# CHANGE COLUMN `character_id` `character_id` VARCHAR(16)  NOT NULL;
# ADD PRIMARY KEY (`character_id`);
# ADD UNIQUE INDEX `character_id_UNIQUE` (`character_id` ASC) VISIBLE;
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
# ALTER TABLE `w4111gotsolution`.`characters`
# CHANGE COLUMN `character_id` `character_id` VARCHAR(16) NOT NULL ;
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 0 rows affected.
# []

# %%
# %sql describe characters
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 11 rows affected.
# [('id', 'int', 'NO', 'PRI', None, ''),
#  ('characterName', 'varchar(64)', 'NO', '', None, ''),
#  ('characterLink', 'varchar(128)', 'YES', '', None, ''),
#  ('actorName', 'varchar(128)', 'YES', '', None, ''),
#  ('actorLink', 'varchar(128)', 'YES', '', None, ''),
#  ('character_id', 'varchar(16)', 'NO', 'UNI', None, ''),
#  ('royal', 'text', 'YES', '', None, ''),
#  ('characterImageThumb', 'varchar(512)', 'YES', '', None, ''),
#  ('characterImageFull', 'varchar(512)', 'YES', '', None, ''),
#  ('nickname', 'varchar(64)', 'YES', '', None, ''),
#  ('kingsguard', 'text', 'YES', '', None, '')]

# %% [markdown]
# - Characters
#    - Convert "" into NULL

# %%
# %sql update characters set actorName=NULL where actorName=""
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 35 rows affected.
# []

# %%
# %sql update characters set characterLink=NULL where characterLink=""
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 21 rows affected.
# []

# %%
# %sql update characters set actorLink=NULL where actorLink=""
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 36 rows affected.
# []

# %%
# %sql update characters set characterImageThumb=NULL where characterImageThumb=""
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 134 rows affected.
# []

# %%
# %sql update characters set nickname	=NULL where nickname=""
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 380 rows affected.
# []

# %% [markdown]
# - Characters
#    - Turn the value of royal and kingsguard into 0 and 1

# %%
# %sql update characters set royal=1 where royal="True"
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 17 rows affected.
# []

# %%
# %sql update characters set royal=0 where royal=""
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 372 rows affected.
# []

# %%
# %sql update characters set kingsguard=1 where kingsguard="True"
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 5 rows affected.
# []

# %%
# %sql update characters set kingsguard=0 where kingsguard=""
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 384 rows affected.
# []

# %%
# %%sql
# ALTER TABLE `w4111gotsolution`.`characters`
# CHANGE COLUMN `royal` `royal` TINYINT NOT NULL DEFAULT 0 ,
# CHANGE COLUMN `kingsguard` `kingsguard` TINYINT NOT NULL DEFAULT 0 ;
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 389 rows affected.
# []

# %%
# %sql describe characters
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 11 rows affected.
# [('id', 'int', 'NO', 'PRI', None, ''),
#  ('characterName', 'varchar(64)', 'NO', '', None, ''),
#  ('characterLink', 'varchar(128)', 'YES', '', None, ''),
#  ('actorName', 'varchar(128)', 'YES', '', None, ''),
#  ('actorLink', 'varchar(128)', 'YES', '', None, ''),
#  ('character_id', 'varchar(16)', 'NO', 'UNI', None, ''),
#  ('royal', 'tinyint', 'NO', '', '0', ''),
#  ('characterImageThumb', 'varchar(512)', 'YES', '', None, ''),
#  ('characterImageFull', 'varchar(512)', 'YES', '', None, ''),
#  ('nickname', 'varchar(64)', 'YES', '', None, ''),
#  ('kingsguard', 'tinyint', 'NO', '', '0', '')]

# %% [markdown]
# - Scenes

# %%
# %sql describe scenes
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 12 rows affected.
# [('id', 'int', 'YES', '', None, ''),
#  ('seasonNum', 'int', 'YES', '', None, ''),
#  ('episodeNum', 'int', 'YES', '', None, ''),
#  ('sceneNo', 'int', 'YES', '', None, ''),
#  ('sceneStart', 'text', 'YES', '', None, ''),
#  ('sceneEnd', 'text', 'YES', '', None, ''),
#  ('location', 'text', 'YES', '', None, ''),
#  ('subLocation', 'text', 'YES', '', None, ''),
#  ('greensight', 'text', 'YES', '', None, ''),
#  ('altLocation', 'text', 'YES', '', None, ''),
#  ('warg', 'text', 'YES', '', None, ''),
#  ('flashback', 'text', 'YES', '', None, '')]

# %% [markdown]
# - Scene
#    - NULL OR NOT NULL ?
#    - Primary key
#    - Unique

# %%
# %%sql
# ALTER TABLE `w4111gotsolution`.`scenes`
# CHANGE COLUMN `id` `id` INT(11) NOT NULL ,
# CHANGE COLUMN `seasonNum` `seasonNum` INT(11) NOT NULL,
# CHANGE COLUMN `episodeNum` `episodeNum` INT(11) NOT NULL ,
# CHANGE COLUMN `sceneNo` `sceneNo` INT(11) NOT NULL ,
# CHANGE COLUMN `sceneStart` `sceneStart` VARCHAR(128) NOT NULL ,
# CHANGE COLUMN `sceneEnd` `sceneEnd` VARCHAR(128) NOT NULL ,
# CHANGE COLUMN `location` `location` VARCHAR(128) NOT NULL ,
# CHANGE COLUMN `subLocation` `subLocation` VARCHAR(128),
# CHANGE COLUMN `greensight` `greensight` VARCHAR(128) ,
# CHANGE COLUMN `altLocation` `altLocation` VARCHAR(128)  ,
# CHANGE COLUMN `warg` `warg` VARCHAR(128) ,
# CHANGE COLUMN `flashback` `flashback` VARCHAR(64)
# ;
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 4165 rows affected.
# []

# %% [markdown]
# - Scenes
#    - Convert "" into NULL

# %%
# %sql update scenes set sublocation=NULL where sublocation=""
# %sql update scenes set greensight=NULL where greensight=""
# %sql update scenes set altLocation=NULL where altLocation=""
# %sql update scenes set warg=NULL where warg=""
# %sql update scenes set flashback=NULL where flashback=""
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 495 rows affected.
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 4149 rows affected.
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 4130 rows affected.
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 4158 rows affected.
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 4124 rows affected.
# []

# %%
# %sql describe scenes
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 12 rows affected.
# [('id', 'int', 'NO', 'PRI', None, ''),
#  ('seasonNum', 'int', 'NO', '', None, ''),
#  ('episodeNum', 'int', 'NO', '', None, ''),
#  ('sceneNo', 'int', 'NO', '', None, ''),
#  ('sceneStart', 'varchar(128)', 'NO', '', None, ''),
#  ('sceneEnd', 'varchar(128)', 'NO', '', None, ''),
#  ('location', 'varchar(128)', 'NO', '', None, ''),
#  ('subLocation', 'varchar(128)', 'YES', '', None, ''),
#  ('greensight', 'varchar(128)', 'YES', '', None, ''),
#  ('altLocation', 'varchar(128)', 'YES', '', None, ''),
#  ('warg', 'varchar(128)', 'YES', '', None, ''),
#  ('flashback', 'varchar(64)', 'YES', '', None, '')]

# %% [markdown]
# - Scenes and Characters

# %%
# %sql describe scenes_characters
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 5 rows affected.
# [('id', 'int', 'YES', '', None, ''),
#  ('seasonNum', 'int', 'YES', '', None, ''),
#  ('episodeNum', 'int', 'YES', '', None, ''),
#  ('sceneNo', 'int', 'YES', '', None, ''),
#  ('characterName', 'text', 'YES', '', None, '')]

# %% [markdown]
# - Scenes and Characters
#    - NULL OR NOT NULL ?
#    - Primary key
#    - Unique

# %%
# %%sql
# ALTER TABLE `w4111gotsolution`.`scenes_characters`
# CHANGE COLUMN `id` `id` INT(11) NOT NULL ,
# CHANGE COLUMN `seasonNum` `seasonNum` INT(11) NOT NULL ,
# CHANGE COLUMN `episodeNum` `episodeNum` INT(11) NOT NULL ,
# CHANGE COLUMN `sceneNo` `sceneNo` INT(11) NOT NULL ,
# CHANGE COLUMN `characterName` `characterName` VARCHAR(128) NOT NULL ,
# ADD PRIMARY KEY (`id`);
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 12114 rows affected.
# []

# %% [markdown]
# Delete scenes not in scenes and charactername not in characters

# %%
# %%sql
# delete from scenes_characters
# where seasonNum not in (select seasonNum from scenes) or  characterName not in (select characterName from characters);
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 515 rows affected.
# []

# %%
# %sql describe scenes_characters
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 5 rows affected.
# [('id', 'int', 'NO', 'PRI', None, ''),
#  ('seasonNum', 'int', 'NO', '', None, ''),
#  ('episodeNum', 'int', 'NO', '', None, ''),
#  ('sceneNo', 'int', 'NO', '', None, ''),
#  ('characterName', 'varchar(128)', 'NO', '', None, '')]

# %% [markdown]
# __characters_actors__

# %% [markdown]
# - characters_actors
#    - NULL OR NOT NULL ?
#    - Primary key
#    - Unique

# %%
# %%sql
# ALTER TABLE `w4111gotsolution`.`characters_actors`
# CHANGE COLUMN `id` `id` INT(11) NOT NULL ,
# CHANGE COLUMN `character_id` `character_id` VARCHAR(64) NOT NULL ,
# CHANGE COLUMN `actorName` `actorName` VARCHAR(64) NOT NULL ,
# CHANGE COLUMN `actorLink` `actorLink` VARCHAR(64) NULL DEFAULT NULL ,
# CHANGE COLUMN `season` `season` VARCHAR(64) NULL DEFAULT NULL ,
# ADD PRIMARY KEY (`id`);
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 408 rows affected.
# []

# %% [markdown]
# - characters_actors
#    - Convert "" into NULL for actorLink
#    - Convert "" into 0 for season

# %%
# %sql update characters_actors set actorLink=NULL where actorLink=""
# %sql update characters_actors set season=NULL where season=""
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 354 rows affected.
# []

# %%
# %sql describe characters_actors
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 5 rows affected.
# [('id', 'int', 'NO', 'PRI', None, ''),
#  ('character_id', 'varchar(64)', 'NO', '', None, ''),
#  ('actorName', 'varchar(64)', 'NO', '', None, ''),
#  ('actorLink', 'varchar(64)', 'YES', '', None, ''),
#  ('season', 'varchar(64)', 'YES', '', None, '')]

# %% [markdown]
# __groups__

# %% [markdown]
# - groups
#    - NULL OR NOT NULL ?
#    - Primary key
#    - Unique

# %%
# %%sql
# ALTER TABLE `w4111gotsolution`.`groups`
# CHANGE COLUMN `id` `id` INT NOT NULL ,
# CHANGE COLUMN `groupName` `groupName` VARCHAR(128) NOT NULL ,
# CHANGE COLUMN `character` `character` VARCHAR(64)
# ;
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 168 rows affected.
# []

# %%
# %sql describe w4111gotsolution.groups
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 3 rows affected.
# [('id', 'int', 'NO', 'PRI', None, ''),
#  ('groupName', 'varchar(128)', 'NO', '', None, ''),
#  ('character', 'varchar(64)', 'YES', '', None, '')]

# %% [markdown]
# __locations__

# %% [markdown]
# - locations
#    - NULL OR NOT NULL ?
#    - Primary key
#    - Unique

# %%
# %%sql
# ALTER TABLE `w4111gotsolution`.`locations`
# CHANGE COLUMN `id` `id` INT(11) NOT NULL ,
# CHANGE COLUMN `location` `location` VARCHAR(64) NOT NULL ,
# CHANGE COLUMN `subLocation` `subLocation` VARCHAR(64) NULL DEFAULT NULL ,
# ADD PRIMARY KEY (`id`);
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 129 rows affected.
# []

# %% [markdown]
# - locations
#    - Convert "" into NULL

# %%
# %sql update locations set subLocation=NULL where subLocation=""
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 26 rows affected.
# []

# %%
# %sql describe locations
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 3 rows affected.
# [('id', 'int', 'NO', 'PRI', None, ''),
#  ('location', 'varchar(64)', 'NO', '', None, ''),
#  ('subLocation', 'varchar(64)', 'YES', '', None, '')]

# %% [markdown]
# <u>Keys and Constraints</u>

# %% [markdown]
# - Characters

# %% [markdown]
# set primary key

# %%
# %%sql
# ALTER TABLE `w4111gotsolution`.`characters`
# DROP PRIMARY KEY,
# ADD PRIMARY KEY (`id`);
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 0 rows affected.
# []

# %% [markdown]
# delete characters not in scenes_character

# %%
# %%sql
# delete from characters where characterName not in (select characterName from scenes_characters);
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 35 rows affected.
# []

# %%
# %sql describe characters
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 11 rows affected.
# [('id', 'int', 'NO', 'PRI', None, ''),
#  ('characterName', 'varchar(64)', 'NO', '', None, ''),
#  ('characterLink', 'varchar(128)', 'YES', '', None, ''),
#  ('actorName', 'varchar(128)', 'YES', '', None, ''),
#  ('actorLink', 'varchar(128)', 'YES', '', None, ''),
#  ('character_id', 'varchar(16)', 'NO', 'UNI', None, ''),
#  ('royal', 'tinyint', 'NO', '', '0', ''),
#  ('characterImageThumb', 'varchar(512)', 'YES', '', None, ''),
#  ('characterImageFull', 'varchar(512)', 'YES', '', None, ''),
#  ('nickname', 'varchar(64)', 'YES', '', None, ''),
#  ('kingsguard', 'tinyint', 'NO', '', '0', '')]

# %% [markdown]
# - Scenes

# %% [markdown]
# set primary key.

# %%
# %%sql
# ALTER TABLE `w4111gotsolution`.`scenes`
# DROP PRIMARY KEY,
# ADD PRIMARY KEY (`seasonNum`, `episodeNum`, `sceneNo`);
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 0 rows affected.
# []

# %% [markdown]
# delete scene not in scenes_characters

# %%
# %%sql
# delete from scenes where (seasonNum,episodeNum,sceneNo) not in (select seasonNum,episodeNum,sceneNo from scenes_characters)
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 341 rows affected.
# []

# %%
# %sql describe scenes
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 12 rows affected.
# [('id', 'int', 'NO', '', None, ''),
#  ('seasonNum', 'int', 'NO', 'PRI', None, ''),
#  ('episodeNum', 'int', 'NO', 'PRI', None, ''),
#  ('sceneNo', 'int', 'NO', 'PRI', None, ''),
#  ('sceneStart', 'varchar(128)', 'NO', '', None, ''),
#  ('sceneEnd', 'varchar(128)', 'NO', '', None, ''),
#  ('location', 'varchar(128)', 'NO', '', None, ''),
#  ('subLocation', 'varchar(128)', 'YES', '', None, ''),
#  ('greensight', 'varchar(128)', 'YES', '', None, ''),
#  ('altLocation', 'varchar(128)', 'YES', '', None, ''),
#  ('warg', 'varchar(128)', 'YES', '', None, ''),
#  ('flashback', 'varchar(64)', 'YES', '', None, '')]

# %% [markdown]
# - Scenes and Characters

# %% [markdown]
# set primary key and foreign key.

# %%
# %%sql
# ALTER TABLE `w4111gotsolution`.`scenes_characters`
# ADD CONSTRAINT `seasonNum,episodeNum,sceneNo`
#   FOREIGN KEY (`seasonNum` , `episodeNum` , `sceneNo`)
#   REFERENCES `w4111gotsolution`.`scenes` (`seasonNum` , `episodeNum` , `sceneNo`)
#   ON DELETE NO ACTION
#   ON UPDATE NO ACTION;
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 11599 rows affected.
# []

# %% [markdown]
# Add a new column named character_id,which could be used as foreign key of table characters

# %%
# %%sql
#
# ALTER TABLE `w4111gotsolution`.`scenes_characters`
# ADD COLUMN `character_id` VARCHAR(64) NULL AFTER `characterName`;
#
# update scenes_characters as a, characters as b
# set a.character_id = b.character_id
# where a.characterName = b.characterName;
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 0 rows affected.
# 11599 rows affected.
# []

# %%
# %%sql
# ALTER TABLE `w4111gotsolution`.`scenes_characters`
# ADD CONSTRAINT `character_id`
#   FOREIGN KEY (`character_id`)
#   REFERENCES `w4111gotsolution`.`characters` (`character_id`)
#   ON DELETE NO ACTION
#   ON UPDATE NO ACTION;
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 11599 rows affected.
# []

# %%
# %sql describe scenes_characters
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 6 rows affected.
# [('id', 'int', 'NO', 'PRI', None, ''),
#  ('seasonNum', 'int', 'NO', 'MUL', None, ''),
#  ('episodeNum', 'int', 'NO', '', None, ''),
#  ('sceneNo', 'int', 'NO', '', None, ''),
#  ('characterName', 'varchar(128)', 'NO', 'MUL', None, ''),
#  ('character_id', 'varchar(64)', 'YES', 'MUL', None, '')]

# %% [markdown]
# <u>Views</u>

# %% [markdown]
# - Character Interaction Views

# %%
# %%sql
# CREATE VIEW `w4111gotsolution`.`djx_ny_cool_guy` as
# select a.characterName as CharacterName1,b.characterName as CharacterName2,count(*) as num
# from scenes_characters a, scenes_characters b
# where a.seasonNum=b.seasonNum and a.episodeNum=b.episodeNum and a.sceneNo=b.sceneNo and a.characterName != b.characterName and a.character_id<b.character_id
# group by a.characterName,b.characterName
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 0 rows affected.
# []

# %% [markdown]
# - Your View and Explanation

# %%
# %sql select * from djx_ny_cool_guy
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 3108 rows affected.
# [('Waymar Royce', 'Gared', 5),
#  ('Waymar Royce', 'Will', 3),
#  ('Will', 'Gared', 4),
#  ('Wight Wildling Girl', 'Will', 2),
#  ('Waymar Royce', 'White Walker', 1),
#  ('White Walker', 'Gared', 2),
#  ('White Walker', 'Will', 1),
#  ('Will', 'Eddard Stark', 2),
#  ('Jon Snow', 'Will', 2),
#  ('Jon Snow', 'Bran Stark', 34),
#  ('Jon Snow', 'Robb Stark', 6),
#  ('Jon Snow', 'Eddard Stark', 6),
#  ('Jon Snow', 'Catelyn Stark', 3),
#  ('Jon Snow', 'Rickon Stark', 9),
#  ('Jon Snow', 'Sansa Stark', 64),
#  ('Jon Snow', 'Arya Stark', 22),
#  ('Jon Snow', 'Theon Greyjoy', 26),
#  ('Jon Snow', 'Rodrik Cassel', 4),
#  ('Jon Snow', 'Septa Mordane', 1),
#  ('Bran Stark', 'Will', 2),
#  ('Bran Stark', 'Eddard Stark', 8),
#  ('Bran Stark', 'Catelyn Stark', 8),
#  ('Bran Stark', 'Sansa Stark', 30),
#  ('Bran Stark', 'Theon Greyjoy', 32),
#  ('Bran Stark', 'Rodrik Cassel', 6),
#  ('Bran Stark', 'Septa Mordane', 1),
#  ('Robb Stark', 'Will', 2),
#  ('Robb Stark', 'Bran Stark', 13),
#  ('Robb Stark', 'Eddard Stark', 5),
#  ('Robb Stark', 'Catelyn Stark', 44),
#  ('Robb Stark', 'Sansa Stark', 2),
#  ('Robb Stark', 'Theon Greyjoy', 21),
#  ('Robb Stark', 'Rodrik Cassel', 14),
#  ('Robb Stark', 'Septa Mordane', 1),
#  ('Catelyn Stark', 'Will', 1),
#  ('Catelyn Stark', 'Eddard Stark', 10),
#  ('Rickon Stark', 'Will', 1),
#  ('Rickon Stark', 'Bran Stark', 24),
#  ('Rickon Stark', 'Robb Stark', 2),
#  ('Rickon Stark', 'Eddard Stark', 2),
#  ('Rickon Stark', 'Catelyn Stark', 2),
#  ('Rickon Stark', 'Sansa Stark', 3),
#  ('Rickon Stark', 'Theon Greyjoy', 4),
#  ('Rickon Stark', 'Rodrik Cassel', 4),
#  ('Rickon Stark', 'Septa Mordane', 1),
#  ('Sansa Stark', 'Will', 1),
#  ('Sansa Stark', 'Eddard Stark', 11),
#  ('Sansa Stark', 'Catelyn Stark', 4),
#  ('Sansa Stark', 'Theon Greyjoy', 27),
#  ('Sansa Stark', 'Septa Mordane', 9),
#  ('Arya Stark', 'Will', 1),
#  ('Arya Stark', 'Bran Stark', 21),
#  ('Arya Stark', 'Robb Stark', 3),
#  ('Arya Stark', 'Eddard Stark', 13),
#  ('Arya Stark', 'Catelyn Stark', 3),
#  ('Arya Stark', 'Rickon Stark', 2),
#  ('Arya Stark', 'Sansa Stark', 42),
#  ('Arya Stark', 'Theon Greyjoy', 5),
#  ('Arya Stark', 'Rodrik Cassel', 3),
#  ('Arya Stark', 'Septa Mordane', 4),
#  ('Theon Greyjoy', 'Will', 2),
#  ('Theon Greyjoy', 'Eddard Stark', 6),
#  ('Theon Greyjoy', 'Catelyn Stark', 11),
#  ('Rodrik Cassel', 'Will', 2),
#  ('Rodrik Cassel', 'Eddard Stark', 6),
#  ('Rodrik Cassel', 'Catelyn Stark', 22),
#  ('Rodrik Cassel', 'Sansa Stark', 3),
#  ('Rodrik Cassel', 'Theon Greyjoy', 15),
#  ('Rodrik Cassel', 'Septa Mordane', 1),
#  ('Septa Mordane', 'Will', 1),
#  ('Septa Mordane', 'Eddard Stark', 5),
#  ('Septa Mordane', 'Catelyn Stark', 1),
#  ('Septa Mordane', 'Theon Greyjoy', 1),
#  ('Jory Cassel', 'Will', 1),
#  ('Jory Cassel', 'Eddard Stark', 15),
#  ('Jory Cassel', 'Robb Stark', 2),
#  ('Jory Cassel', 'Theon Greyjoy', 3),
#  ('Jory Cassel', 'Bran Stark', 3),
#  ('Jory Cassel', 'Rodrik Cassel', 4),
#  ('Jon Snow', 'Jory Cassel', 3),
#  ('Jon Snow', 'Grey Wind', 1),
#  ('Jon Snow', 'Lady', 1),
#  ('Jon Snow', 'Nymeria', 2),
#  ('Jon Snow', 'Summer', 3),
#  ('Jon Snow', 'Shaggydog', 3),
#  ('Jon Snow', 'Ghost', 36),
#  ('Eddard Stark', 'Grey Wind', 1),
#  ('Eddard Stark', 'Ghost', 1),
#  ('Theon Greyjoy', 'Grey Wind', 3),
#  ('Theon Greyjoy', 'Ghost', 2),
#  ('Bran Stark', 'Grey Wind', 3),
#  ('Bran Stark', 'Summer', 35),
#  ('Bran Stark', 'Shaggydog', 7),
#  ('Bran Stark', 'Ghost', 5),
#  ('Robb Stark', 'Grey Wind', 6),
#  ('Robb Stark', 'Summer', 3),
#  ('Robb Stark', 'Shaggydog', 1),
#  ('Robb Stark', 'Ghost', 1),
#  ('Rodrik Cassel', 'Grey Wind', 1),
#  ('Rodrik Cassel', 'Summer', 2),
#  ('Rodrik Cassel', 'Shaggydog', 1),
#  ('Rodrik Cassel', 'Ghost', 1),
#  ('Jory Cassel', 'Grey Wind', 1),
#  ('Jory Cassel', 'Lady', 1),
#  ('Jory Cassel', 'Nymeria', 1),
#  ('Jory Cassel', 'Summer', 2),
#  ('Jory Cassel', 'Shaggydog', 1),
#  ('Jory Cassel', 'Ghost', 1),
#  ('Lady', 'Eddard Stark', 3),
#  ('Lady', 'Theon Greyjoy', 1),
#  ('Lady', 'Bran Stark', 1),
#  ('Lady', 'Robb Stark', 1),
#  ('Lady', 'Rodrik Cassel', 1),
#  ('Lady', 'Grey Wind', 1),
#  ('Lady', 'Nymeria', 1),
#  ('Lady', 'Summer', 1),
#  ('Lady', 'Shaggydog', 1),
#  ('Lady', 'Ghost', 1),
#  ('Nymeria', 'Eddard Stark', 1),
#  ('Nymeria', 'Theon Greyjoy', 1),
#  ('Nymeria', 'Bran Stark', 1),
#  ('Nymeria', 'Robb Stark', 1),
#  ('Nymeria', 'Rodrik Cassel', 1),
#  ('Nymeria', 'Grey Wind', 1),
#  ('Nymeria', 'Summer', 1),
#  ('Nymeria', 'Shaggydog', 1),
#  ('Nymeria', 'Ghost', 1),
#  ('Summer', 'Eddard Stark', 3),
#  ('Summer', 'Theon Greyjoy', 4),
#  ('Summer', 'Grey Wind', 1),
#  ('Summer', 'Ghost', 2),
#  ('Shaggydog', 'Eddard Stark', 1),
#  ('Shaggydog', 'Theon Greyjoy', 1),
#  ('Shaggydog', 'Grey Wind', 1),
#  ('Shaggydog', 'Summer', 8),
#  ('Shaggydog', 'Ghost', 1),
#  ('Ghost', 'Grey Wind', 1),
#  ('Jon Arryn', 'Cersei Lannister', 1),
#  ('Jaime Lannister', 'Jon Arryn', 1),
#  ('Jaime Lannister', 'Cersei Lannister', 81),
#  ('Maester Luwin', 'Catelyn Stark', 5),
#  ('Bran Stark', 'Sandor Clegane', 6),
#  ('Bran Stark', 'Cersei Lannister', 3),
#  ('Bran Stark', 'Tommen Baratheon', 1),
#  ('Catelyn Stark', 'Cersei Lannister', 4),
#  ('Maester Luwin', 'Bran Stark', 13),
#  ('Maester Luwin', 'Summer', 2),
#  ('Maester Luwin', 'Sandor Clegane', 1),
#  ('Maester Luwin', 'Rickon Stark', 7),
#  ('Maester Luwin', 'Eddard Stark', 2),
#  ('Maester Luwin', 'Sansa Stark', 1),
#  ('Maester Luwin', 'Theon Greyjoy', 14),
#  ('Maester Luwin', 'Rodrik Cassel', 4),
#  ('Maester Luwin', 'Robert Baratheon', 1),
#  ('Maester Luwin', 'Cersei Lannister', 1),
#  ('Maester Luwin', 'Myrcella Baratheon', 1),
#  ('Maester Luwin', 'Tommen Baratheon', 1),
#  ('Summer', 'Catelyn Stark', 2),
#  ('Summer', 'Cersei Lannister', 2),
#  ('Summer', 'Tommen Baratheon', 1),
#  ('Arya Stark', 'Maester Luwin', 1),
#  ('Arya Stark', 'Summer', 1),
#  ('Arya Stark', 'Sandor Clegane', 67),
#  ('Arya Stark', 'Robert Baratheon', 4),
#  ('Arya Stark', 'Cersei Lannister', 5),
#  ('Arya Stark', 'Myrcella Baratheon', 2),
#  ('Arya Stark', 'Tommen Baratheon', 2),
#  ('Joffrey Baratheon', 'Bran Stark', 1),
#  ('Joffrey Baratheon', 'Catelyn Stark', 2),
#  ('Joffrey Baratheon', 'Maester Luwin', 1),
#  ('Joffrey Baratheon', 'Summer', 1),
#  ('Joffrey Baratheon', 'Arya Stark', 6),
#  ('Joffrey Baratheon', 'Sandor Clegane', 30),
#  ('Joffrey Baratheon', 'Rickon Stark', 1),
#  ('Joffrey Baratheon', 'Eddard Stark', 8),
#  ('Joffrey Baratheon', 'Sansa Stark', 51),
#  ('Joffrey Baratheon', 'Theon Greyjoy', 2),
#  ('Joffrey Baratheon', 'Jon Snow', 1),
#  ('Joffrey Baratheon', 'Jory Cassel', 2),
#  ('Joffrey Baratheon', 'Rodrik Cassel', 2),
#  ('Joffrey Baratheon', 'Robert Baratheon', 6),
#  ('Joffrey Baratheon', 'Cersei Lannister', 60),
#  ('Joffrey Baratheon', 'Myrcella Baratheon', 4),
#  ('Joffrey Baratheon', 'Tommen Baratheon', 31),
#  ('Sandor Clegane', 'Catelyn Stark', 1),
#  ('Sandor Clegane', 'Summer', 2),
#  ('Sandor Clegane', 'Eddard Stark', 8),
#  ('Sandor Clegane', 'Sansa Stark', 31),
#  ('Sandor Clegane', 'Theon Greyjoy', 14),
#  ('Sandor Clegane', 'Cersei Lannister', 16),
#  ('Sandor Clegane', 'Tommen Baratheon', 7),
#  ('Rickon Stark', 'Summer', 7),
#  ('Rickon Stark', 'Sandor Clegane', 1),
#  ('Rickon Stark', 'Robert Baratheon', 1),
#  ('Rickon Stark', 'Cersei Lannister', 1),
#  ('Rickon Stark', 'Tommen Baratheon', 1),
#  ('Sansa Stark', 'Summer', 1),
#  ('Sansa Stark', 'Cersei Lannister', 48),
#  ('Sansa Stark', 'Tommen Baratheon', 29),
#  ('Theon Greyjoy', 'Cersei Lannister', 9),
#  ('Theon Greyjoy', 'Tommen Baratheon', 1),
#  ('Jon Snow', 'Maester Luwin', 1),
#  ('Jon Snow', 'Sandor Clegane', 42),
#  ('Jon Snow', 'Robert Baratheon', 1),
#  ('Jon Snow', 'Cersei Lannister', 8),
#  ('Jon Snow', 'Myrcella Baratheon', 1),
#  ('Jon Snow', 'Tommen Baratheon', 1),
#  ('Jory Cassel', 'Catelyn Stark', 2),
#  ('Jory Cassel', 'Maester Luwin', 1),
#  ('Jory Cassel', 'Arya Stark', 5),
#  ('Jory Cassel', 'Sandor Clegane', 1),
#  ('Jory Cassel', 'Rickon Stark', 1),
#  ('Jory Cassel', 'Sansa Stark', 3),
#  ('Jory Cassel', 'Robert Baratheon', 2),
#  ('Jory Cassel', 'Cersei Lannister', 3),
#  ('Jory Cassel', 'Myrcella Baratheon', 1),
#  ('Jory Cassel', 'Tommen Baratheon', 1),
#  ('Hodor', 'Bran Stark', 76),
#  ('Hodor', 'Catelyn Stark', 1),
#  ('Hodor', 'Maester Luwin', 9),
#  ('Hodor', 'Summer', 24),
#  ('Hodor', 'Arya Stark', 1),
#  ('Hodor', 'Joffrey Baratheon', 1),
#  ('Hodor', 'Sandor Clegane', 1),
#  ('Hodor', 'Rickon Stark', 20),
#  ('Hodor', 'Eddard Stark', 1),
#  ('Hodor', 'Sansa Stark', 1),
#  ('Hodor', 'Theon Greyjoy', 6),
#  ('Hodor', 'Jon Snow', 2),
#  ('Hodor', 'Jory Cassel', 1),
#  ('Hodor', 'Rodrik Cassel', 3),
#  ('Hodor', 'Robert Baratheon', 1),
#  ('Hodor', 'Cersei Lannister', 1),
#  ('Hodor', 'Jaime Lannister', 1),
#  ('Hodor', 'Myrcella Baratheon', 1),
#  ('Hodor', 'Tommen Baratheon', 1),
#  ('Rodrik Cassel', 'Sandor Clegane', 1),
#  ('Rodrik Cassel', 'Cersei Lannister', 3),
#  ('Rodrik Cassel', 'Tommen Baratheon', 1),
#  ('Robert Baratheon', 'Bran Stark', 2),
#  ('Robert Baratheon', 'Catelyn Stark', 3),
#  ('Robert Baratheon', 'Summer', 2),
#  ('Robert Baratheon', 'Sandor Clegane', 4),
#  ('Robert Baratheon', 'Eddard Stark', 13),
#  ('Robert Baratheon', 'Sansa Stark', 5),
#  ('Robert Baratheon', 'Theon Greyjoy', 3),
#  ('Robert Baratheon', 'Rodrik Cassel', 3),
#  ('Robert Baratheon', 'Cersei Lannister', 8),
#  ('Robert Baratheon', 'Tommen Baratheon', 3),
#  ('Cersei Lannister', 'Eddard Stark', 9),
#  ('Jaime Lannister', 'Bran Stark', 19),
#  ('Jaime Lannister', 'Catelyn Stark', 7),
#  ('Jaime Lannister', 'Maester Luwin', 1),
#  ('Jaime Lannister', 'Summer', 2),
#  ('Jaime Lannister', 'Arya Stark', 8),
#  ('Jaime Lannister', 'Joffrey Baratheon', 17),
#  ('Jaime Lannister', 'Sandor Clegane', 9),
#  ('Jaime Lannister', 'Rickon Stark', 1),
#  ('Jaime Lannister', 'Eddard Stark', 4),
#  ('Jaime Lannister', 'Sansa Stark', 20),
#  ('Jaime Lannister', 'Theon Greyjoy', 12),
#  ('Jaime Lannister', 'Jon Snow', 22),
#  ('Jaime Lannister', 'Jory Cassel', 3),
#  ('Jaime Lannister', 'Rodrik Cassel', 3),
#  ('Jaime Lannister', 'Robert Baratheon', 3),
#  ('Jaime Lannister', 'Myrcella Baratheon', 15),
#  ('Jaime Lannister', 'Tommen Baratheon', 17),
#  ('Myrcella Baratheon', 'Bran Stark', 1),
#  ('Myrcella Baratheon', 'Catelyn Stark', 1),
#  ('Myrcella Baratheon', 'Summer', 1),
#  ('Myrcella Baratheon', 'Sandor Clegane', 5),
#  ('Myrcella Baratheon', 'Rickon Stark', 1),
#  ('Myrcella Baratheon', 'Eddard Stark', 2),
#  ('Myrcella Baratheon', 'Sansa Stark', 5),
#  ('Myrcella Baratheon', 'Theon Greyjoy', 1),
#  ('Myrcella Baratheon', 'Rodrik Cassel', 1),
#  ('Myrcella Baratheon', 'Robert Baratheon', 3),
#  ('Myrcella Baratheon', 'Cersei Lannister', 5),
#  ('Myrcella Baratheon', 'Tommen Baratheon', 9),
#  ('Tommen Baratheon', 'Catelyn Stark', 1),
#  ('Tommen Baratheon', 'Eddard Stark', 2),
#  ('Tommen Baratheon', 'Cersei Lannister', 65),
#  ('Jaime Lannister', 'Tyrion Lannister', 74),
#  ('Jaime Lannister', 'Ros', 1),
#  ('Ros', 'Tyrion Lannister', 3),
#  ('Viserys Targaryen', 'Daenerys Targaryen', 10),
#  ('Illyrio Mopatis', 'Daenerys Targaryen', 3),
#  ('Illyrio Mopatis', 'Viserys Targaryen', 3),
#  ('Illyrio Mopatis', 'Khal Drogo', 2),
#  ('Illyrio Mopatis', 'Qotho', 2),
#  ('Khal Drogo', 'Daenerys Targaryen', 22),
#  ('Khal Drogo', 'Viserys Targaryen', 7),
#  ('Khal Drogo', 'Qotho', 7),
#  ('Qotho', 'Daenerys Targaryen', 7),
#  ('Qotho', 'Viserys Targaryen', 3),
#  ('Jon Snow', 'Benjen Stark', 6),
#  ('Jon Snow', 'Tyrion Lannister', 82),
#  ('Benjen Stark', 'Tyrion Lannister', 6),
#  ('Benjen Stark', 'Rodrik Cassel', 1),
#  ('Benjen Stark', 'Eddard Stark', 3),
#  ('Benjen Stark', 'Robb Stark', 2),
#  ('Benjen Stark', 'Robert Baratheon', 2),
#  ('Benjen Stark', 'Catelyn Stark', 1),
#  ('Benjen Stark', 'Cersei Lannister', 1),
#  ('Benjen Stark', 'Sansa Stark', 1),
#  ('Benjen Stark', 'Theon Greyjoy', 2),
#  ('Robb Stark', 'Robert Baratheon', 2),
#  ('Robb Stark', 'Cersei Lannister', 1),
#  ('Joffrey Baratheon', 'Benjen Stark', 1),
#  ('Joffrey Baratheon', 'Robb Stark', 1),
#  ('Jaime Lannister', 'Benjen Stark', 1),
#  ('Jaime Lannister', 'Robb Stark', 4),
#  ('Arya Stark', 'Benjen Stark', 1),
#  ('Khal Drogo', 'Drogon', 5),
#  ('Khal Drogo', 'Rhaegal', 5),
#  ('Khal Drogo', 'Viserion', 5),
#  ('Daenerys Targaryen', 'Drogon', 172),
#  ('Viserys Targaryen', 'Drogon', 2),
#  ('Illyrio Mopatis', 'Jorah Mormont', 1),
#  ('Illyrio Mopatis', 'Drogon', 1),
#  ('Illyrio Mopatis', 'Rhaegal', 1),
#  ('Illyrio Mopatis', 'Viserion', 1),
#  ('Qotho', 'Drogon', 1),
#  ('Qotho', 'Rhaegal', 1),
#  ('Qotho', 'Viserion', 1),
#  ('Jorah Mormont', 'Khal Drogo', 12),
#  ('Jorah Mormont', 'Daenerys Targaryen', 148),
#  ('Jorah Mormont', 'Viserys Targaryen', 7),
#  ('Jorah Mormont', 'Qotho', 5),
#  ('Jorah Mormont', 'Drogon', 25),
#  ('Jorah Mormont', 'Rhaegal', 17),
#  ('Jorah Mormont', 'Viserion', 13),
#  ('Rhaegal', 'Daenerys Targaryen', 59),
#  ('Rhaegal', 'Viserys Targaryen', 2),
#  ('Rhaegal', 'Drogon', 64),
#  ('Rhaegal', 'Viserion', 50),
#  ('Viserion', 'Daenerys Targaryen', 40),
#  ('Viserion', 'Viserys Targaryen', 2),
#  ('Viserion', 'Drogon', 40),
#  ('Tyrion Lannister', 'Eddard Stark', 2),
#  ('Sandor Clegane', 'Tyrion Lannister', 31),
#  ('Theon Greyjoy', 'Tyrion Lannister', 24),
#  ('Benjen Stark', 'Sandor Clegane', 1),
#  ('Benjen Stark', 'Bran Stark', 4),
#  ('Benjen Stark', 'Summer', 1),
#  ('Robb Stark', 'Tyrion Lannister', 2),
#  ('Robb Stark', 'Sandor Clegane', 2),
#  ('Robert Baratheon', 'Tyrion Lannister', 1),
#  ('Bran Stark', 'Tyrion Lannister', 32),
#  ('Summer', 'Tyrion Lannister', 1),
#  ('Jorah Mormont', 'Doreah', 13),
#  ('Daenerys Targaryen', 'Doreah', 19),
#  ('Khal Drogo', 'Doreah', 5),
#  ('Viserys Targaryen', 'Doreah', 5),
#  ('Irri', 'Jorah Mormont', 12),
#  ('Irri', 'Daenerys Targaryen', 18),
#  ('Irri', 'Khal Drogo', 7),
#  ('Irri', 'Viserys Targaryen', 5),
#  ('Irri', 'Doreah', 13),
#  ('Irri', 'Jhiqui', 2),
#  ('Jhiqui', 'Jorah Mormont', 1),
#  ('Jhiqui', 'Daenerys Targaryen', 2),
#  ('Jhiqui', 'Khal Drogo', 1),
#  ('Jhiqui', 'Viserys Targaryen', 1),
#  ('Jhiqui', 'Doreah', 2),
#  ('Joffrey Baratheon', 'Tyrion Lannister', 52),
#  ('Tyrion Lannister', 'Cersei Lannister', 82),
#  ('Tommen Baratheon', 'Tyrion Lannister', 24),
#  ('Myrcella Baratheon', 'Tyrion Lannister', 3),
#  ('Arya Stark', 'Nymeria', 4),
#  ('Jon Snow', 'Rast', 11),
#  ('Benjen Stark', 'Ghost', 1),
#  ('Benjen Stark', 'Rast', 1),
#  ('Tyrion Lannister', 'Ghost', 5),
#  ('Rast', 'Ghost', 5),
#  ('Rast', 'Tyrion Lannister', 4),
#  ('Catelyn Stark', 'Catspaw Assassin', 1),
#  ('Bran Stark', 'Catspaw Assassin', 1),
#  ('Maester Luwin', 'Robb Stark', 4),
#  ('Maester Luwin', 'Catspaw Assassin', 1),
#  ('Robb Stark', 'Catspaw Assassin', 1),
#  ('Summer', 'Catspaw Assassin', 1),
#  ('Doreah', 'Drogon', 6),
#  ('Irri', 'Drogon', 3),
#  ('Irri', 'Rhaegal', 3),
#  ('Irri', 'Viserion', 3),
#  ('Jhiqui', 'Drogon', 1),
#  ('Jhiqui', 'Rhaegal', 1),
#  ('Jhiqui', 'Viserion', 1),
#  ('Rhaegal', 'Doreah', 4),
#  ('Viserion', 'Doreah', 4),
#  ('Lady', 'Sansa Stark', 1),
#  ('Lady', 'Sandor Clegane', 1),
#  ('Joffrey Baratheon', 'Lady', 1),
#  ('Ilyn Payne', 'Sansa Stark', 10),
#  ('Ilyn Payne', 'Lady', 1),
#  ('Ilyn Payne', 'Joffrey Baratheon', 4),
#  ('Ilyn Payne', 'Sandor Clegane', 4),
#  ('Arya Stark', 'Mycah', 1),
#  ('Mycah', 'Sansa Stark', 1),
#  ('Mycah', 'Nymeria', 1),
#  ('Joffrey Baratheon', 'Mycah', 1),
#  ('Joffrey Baratheon', 'Nymeria', 1),
#  ('Nymeria', 'Sansa Stark', 1),
#  ('Ilyn Payne', 'Eddard Stark', 4),
#  ('Ilyn Payne', 'Arya Stark', 3),
#  ('Ilyn Payne', 'Cersei Lannister', 8),
#  ('Ilyn Payne', 'Robert Baratheon', 1),
#  ('Ilyn Payne', 'Jory Cassel', 1),
#  ('Mycah', 'Sandor Clegane', 1),
#  ('Mycah', 'Eddard Stark', 1),
#  ('Arya Stark', 'Royal Steward', 1),
#  ('Jory Cassel', 'Septa Mordane', 1),
#  ('Jory Cassel', 'Royal Steward', 1),
#  ('Royal Steward', 'Eddard Stark', 5),
#  ('Royal Steward', 'Sansa Stark', 2),
#  ('Royal Steward', 'Septa Mordane', 1),
#  ('Eddard Stark', 'Grand Maester Pycelle', 10),
#  ('Lord Varys', 'Eddard Stark', 12),
#  ('Lord Varys', 'Grand Maester Pycelle', 23),
#  ('Lord Varys', 'Renly Baratheon', 5),
#  ('Lord Varys', 'Petyr Baelish', 19),
#  ('Renly Baratheon', 'Eddard Stark', 8),
#  ('Renly Baratheon', 'Grand Maester Pycelle', 6),
#  ('Petyr Baelish', 'Eddard Stark', 17),
#  ('Petyr Baelish', 'Grand Maester Pycelle', 15),
#  ('Petyr Baelish', 'Renly Baratheon', 9),
#  ('Old Nan', 'Bran Stark', 2),
#  ('Old Nan', 'Robb Stark', 1),
#  ('Petyr Baelish', 'Rodrik Cassel', 1),
#  ('Petyr Baelish', 'Catelyn Stark', 4),
#  ('Lord Varys', 'Rodrik Cassel', 1),
#  ('Lord Varys', 'Catelyn Stark', 1),
#  ('Tyrion Lannister', 'Alliser Thorne', 1),
#  ('Tyrion Lannister', 'Grenn', 3),
#  ('Jeor Mormont', 'Tyrion Lannister', 2),
#  ('Jeor Mormont', 'Alliser Thorne', 3),
#  ('Jeor Mormont', 'Jon Snow', 17),
#  ('Jeor Mormont', 'Pypar', 4),
#  ('Jeor Mormont', 'Grenn', 14),
#  ('Jeor Mormont', 'Rast', 11),
#  ('Alliser Thorne', 'Grenn', 13),
#  ('Jon Snow', 'Alliser Thorne', 37),
#  ('Jon Snow', 'Pypar', 20),
#  ('Jon Snow', 'Grenn', 45),
#  ('Pypar', 'Tyrion Lannister', 3),
#  ('Pypar', 'Alliser Thorne', 10),
#  ('Pypar', 'Grenn', 17),
#  ('Pypar', 'Rast', 10),
#  ('Rast', 'Alliser Thorne', 4),
#  ('Rast', 'Grenn', 18),
#  ('Barristan Selmy', 'Robert Baratheon', 5),
#  ('Lancel Lannister', 'Robert Baratheon', 3),
#  ('Lancel Lannister', 'Barristan Selmy', 2),
#  ('Jaime Lannister', 'Barristan Selmy', 1),
#  ('Jaime Lannister', 'Lancel Lannister', 2),
#  ('Khal Drogo', 'Rakharo', 7),
#  ('Jorah Mormont', 'Rakharo', 13),
#  ('Rakharo', 'Daenerys Targaryen', 14),
#  ('Rakharo', 'Viserys Targaryen', 1),
#  ('Irri', 'Rakharo', 9),
#  ('Tyrion Lannister', 'Yoren', 3),
#  ('Benjen Stark', 'Yoren', 1),
#  ('Jon Snow', 'Maester Aemon', 11),
#  ('Maester Aemon', 'Tyrion Lannister', 1),
#  ('Maester Aemon', 'Pypar', 4),
#  ('Maester Aemon', 'Grenn', 4),
#  ('Maester Aemon', 'Rast', 2),
#  ('Jeor Mormont', 'Maester Aemon', 2),
#  ('Arya Stark', 'Syrio Forel', 5),
#  ('Syrio Forel', 'Eddard Stark', 1),
#  ('Bran Stark', 'Three-Eyed Raven', 38),
#  ('Old Nan', 'Summer', 1),
#  ('Old Nan', 'Theon Greyjoy', 1),
#  ('Hodor', 'Old Nan', 1),
#  ('Tyrion Lannister', 'Grey Wind', 1),
#  ('Robb Stark', 'Yoren', 1),
#  ('Maester Luwin', 'Tyrion Lannister', 1),
#  ('Maester Luwin', 'Yoren', 1),
#  ('Maester Luwin', 'Grey Wind', 1),
#  ('Yoren', 'Grey Wind', 1),
#  ('Hodor', 'Tyrion Lannister', 1),
#  ('Hodor', 'Robb Stark', 1),
#  ('Hodor', 'Yoren', 1),
#  ('Hodor', 'Grey Wind', 1),
#  ('Bran Stark', 'Yoren', 1),
#  ('Theon Greyjoy', 'Yoren', 1),
#  ('Jon Snow', 'Samwell Tarly', 80),
#  ('Samwell Tarly', 'Grenn', 30),
#  ('Samwell Tarly', 'Alliser Thorne', 20),
#  ('Pypar', 'Samwell Tarly', 18),
#  ('Rast', 'Samwell Tarly', 14),
#  ('Janos Slynt', 'Eddard Stark', 3),
#  ('Janos Slynt', 'Petyr Baelish', 6),
#  ('Janos Slynt', 'Renly Baratheon', 1),
#  ('Janos Slynt', 'Grand Maester Pycelle', 4),
#  ('Janos Slynt', 'Lord Varys', 6),
#  ('Hugh of the Vale', 'Jory Cassel', 1),
#  ('Eddard Stark', 'Gendry', 1),
#  ('Tobho Mott', 'Eddard Stark', 1),
#  ('Tobho Mott', 'Gendry', 1),
#  ('Pypar', 'Ghost', 2),
#  ('Ghost', 'Grenn', 6),
#  ('Robert Baratheon', 'Septa Mordane', 2),
#  ('Robert Baratheon', 'Gregor Clegane', 2),
#  ('Cersei Lannister', 'Gregor Clegane', 67),
#  ('Tommen Baratheon', 'Gregor Clegane', 7),
#  ('Myrcella Baratheon', 'Petyr Baelish', 2),
#  ('Myrcella Baratheon', 'Septa Mordane', 2),
#  ('Myrcella Baratheon', 'Gregor Clegane', 2),
#  ('Myrcella Baratheon', 'Renly Baratheon', 2),
#  ('Barristan Selmy', 'Cersei Lannister', 4),
#  ('Barristan Selmy', 'Tommen Baratheon', 2),
#  ('Barristan Selmy', 'Myrcella Baratheon', 2),
#  ('Barristan Selmy', 'Sansa Stark', 3),
#  ('Barristan Selmy', 'Petyr Baelish', 4),
#  ('Barristan Selmy', 'Septa Mordane', 2),
#  ('Barristan Selmy', 'Sandor Clegane', 4),
#  ('Barristan Selmy', 'Gregor Clegane', 2),
#  ('Barristan Selmy', 'Renly Baratheon', 5),
#  ('Joffrey Baratheon', 'Barristan Selmy', 5),
#  ('Joffrey Baratheon', 'Petyr Baelish', 8),
#  ('Joffrey Baratheon', 'Septa Mordane', 4),
#  ('Joffrey Baratheon', 'Gregor Clegane', 2),
#  ('Joffrey Baratheon', 'Renly Baratheon', 3),
#  ('Sansa Stark', 'Gregor Clegane', 2),
#  ('Petyr Baelish', 'Robert Baratheon', 3),
#  ('Petyr Baelish', 'Cersei Lannister', 14),
#  ('Petyr Baelish', 'Tommen Baratheon', 2),
#  ('Petyr Baelish', 'Sansa Stark', 58),
#  ('Petyr Baelish', 'Septa Mordane', 2),
#  ('Petyr Baelish', 'Sandor Clegane', 5),
#  ('Petyr Baelish', 'Gregor Clegane', 2),
#  ('Septa Mordane', 'Cersei Lannister', 1),
#  ('Septa Mordane', 'Tommen Baratheon', 2),
#  ('Septa Mordane', 'Gregor Clegane', 2),
#  ('Arya Stark', 'Barristan Selmy', 1),
#  ('Arya Stark', 'Petyr Baelish', 11),
#  ('Arya Stark', 'Gregor Clegane', 5),
#  ('Arya Stark', 'Renly Baratheon', 1),
#  ('Sandor Clegane', 'Septa Mordane', 3),
#  ('Sandor Clegane', 'Gregor Clegane', 19),
#  ('Hugh of the Vale', 'Robert Baratheon', 1),
#  ('Hugh of the Vale', 'Cersei Lannister', 1),
#  ('Hugh of the Vale', 'Tommen Baratheon', 1),
#  ('Hugh of the Vale', 'Myrcella Baratheon', 1),
#  ('Hugh of the Vale', 'Barristan Selmy', 2),
#  ('Hugh of the Vale', 'Joffrey Baratheon', 1),
#  ('Hugh of the Vale', 'Sansa Stark', 1),
#  ('Hugh of the Vale', 'Petyr Baelish', 1),
#  ('Hugh of the Vale', 'Septa Mordane', 1),
#  ('Hugh of the Vale', 'Arya Stark', 1),
#  ('Hugh of the Vale', 'Sandor Clegane', 1),
#  ('Hugh of the Vale', 'Gregor Clegane', 1),
#  ('Hugh of the Vale', 'Renly Baratheon', 1),
#  ('Renly Baratheon', 'Robert Baratheon', 5),
#  ('Renly Baratheon', 'Cersei Lannister', 2),
#  ('Renly Baratheon', 'Tommen Baratheon', 2),
#  ('Renly Baratheon', 'Sansa Stark', 2),
#  ('Renly Baratheon', 'Septa Mordane', 2),
#  ('Renly Baratheon', 'Sandor Clegane', 2),
#  ('Renly Baratheon', 'Gregor Clegane', 2),
#  ('Catelyn Stark', 'Yoren', 1),
#  ('Rodrik Cassel', 'Tyrion Lannister', 5),
#  ('Rodrik Cassel', 'Yoren', 1),
#  ('Rodrik Cassel', 'Bronn', 5),
#  ('Marillion', 'Catelyn Stark', 2),
#  ('Marillion', 'Rodrik Cassel', 2),
#  ('Marillion', 'Tyrion Lannister', 2),
#  ('Marillion', 'Yoren', 1),
#  ('Marillion', 'Bronn', 2),
#  ('Tyrion Lannister', 'Catelyn Stark', 6),
#  ('Bronn', 'Catelyn Stark', 5),
#  ('Bronn', 'Tyrion Lannister', 59),
#  ('Bronn', 'Yoren', 1),
#  ('Hugh of the Vale', 'Eddard Stark', 1),
#  ('Barristan Selmy', 'Eddard Stark', 6),
#  ('Lancel Lannister', 'Eddard Stark', 1),
#  ('Joffrey Baratheon', 'Grand Maester Pycelle', 17),
#  ('Joffrey Baratheon', 'Loras Tyrell', 9),
#  ('Eddard Stark', 'Gregor Clegane', 1),
#  ('Sansa Stark', 'Grand Maester Pycelle', 14),
#  ('Septa Mordane', 'Grand Maester Pycelle', 1),
#  ('Grand Maester Pycelle', 'Gregor Clegane', 10),
#  ('Loras Tyrell', 'Gregor Clegane', 1),
#  ('Loras Tyrell', 'Eddard Stark', 1),
#  ('Loras Tyrell', 'Sansa Stark', 12),
#  ('Loras Tyrell', 'Petyr Baelish', 5),
#  ('Loras Tyrell', 'Septa Mordane', 1),
#  ('Loras Tyrell', 'Renly Baratheon', 6),
#  ('Loras Tyrell', 'Grand Maester Pycelle', 9),
#  ('Loras Tyrell', 'Robert Baratheon', 1),
#  ('Loras Tyrell', 'Sandor Clegane', 1),
#  ('Loras Tyrell', 'Barristan Selmy', 1),
#  ('Loras Tyrell', 'Myrcella Baratheon', 1),
#  ('Loras Tyrell', 'Tommen Baratheon', 11),
#  ('Robert Baratheon', 'Grand Maester Pycelle', 3),
#  ('Sandor Clegane', 'Grand Maester Pycelle', 3),
#  ('Barristan Selmy', 'Grand Maester Pycelle', 4),
#  ('Myrcella Baratheon', 'Grand Maester Pycelle', 1),
#  ('Tommen Baratheon', 'Grand Maester Pycelle', 17),
#  ('Ros', 'Theon Greyjoy', 2),
#  ('Jory Cassel', 'Lord Varys', 1),
#  ('Arya Stark', 'Lord Varys', 10),
#  ('Illyrio Mopatis', 'Arya Stark', 1),
#  ('Illyrio Mopatis', 'Lord Varys', 1),
#  ('Arya Stark', 'Yoren', 12),
#  ('Jory Cassel', 'Yoren', 1),
#  ('Yoren', 'Eddard Stark', 4),
#  ('Tyrion Lannister', 'Vardis Egen', 4),
#  ('Rodrik Cassel', 'Vardis Egen', 3),
#  ('Bronn', 'Vardis Egen', 3),
#  ('Vardis Egen', 'Catelyn Stark', 4),
#  ('Lord Varys', 'Robert Baratheon', 1),
#  ('Jory Cassel', 'Petyr Baelish', 3),
#  ('Lysa Arryn', 'Catelyn Stark', 4),
#  ('Lysa Arryn', 'Tyrion Lannister', 3),
#  ('Lysa Arryn', 'Robin Arryn', 5),
#  ('Lysa Arryn', 'Vardis Egen', 3),
#  ('Robin Arryn', 'Catelyn Stark', 4),
#  ('Robin Arryn', 'Tyrion Lannister', 6),
#  ('Robin Arryn', 'Vardis Egen', 3),
#  ('Mord', 'Tyrion Lannister', 4),
#  ('Mhaegen', 'Eddard Stark', 1),
#  ('Jaime Lannister', 'Petyr Baelish', 1),
#  ('Bran Stark', 'Stiv', 1),
#  ('Bran Stark', 'Wallen', 1),
#  ('Osha', 'Bran Stark', 31),
#  ('Osha', 'Stiv', 1),
#  ('Osha', 'Wallen', 1),
#  ('Osha', 'Robb Stark', 1),
#  ('Osha', 'Theon Greyjoy', 7),
#  ('Stiv', 'Wallen', 1),
#  ('Stiv', 'Theon Greyjoy', 1),
#  ('Robb Stark', 'Stiv', 1),
#  ('Robb Stark', 'Wallen', 1),
#  ('Theon Greyjoy', 'Wallen', 1),
#  ('Khal Drogo', 'Rhaego', 2),
#  ('Jorah Mormont', 'Rhaego', 2),
#  ('Irri', 'Rhaego', 1),
#  ('Rhaego', 'Daenerys Targaryen', 3),
#  ('Rhaego', 'Viserys Targaryen', 1),
#  ('Rhaego', 'Doreah', 1),
#  ('Lysa Arryn', 'Bronn', 2),
#  ('Lysa Arryn', 'Rodrik Cassel', 2),
#  ('Robin Arryn', 'Bronn', 2),
#  ('Robin Arryn', 'Rodrik Cassel', 2),
#  ('Lancel Lannister', 'Renly Baratheon', 1),
#  ('Beric Dondarrion', 'Eddard Stark', 1),
#  ('Beric Dondarrion', 'Grand Maester Pycelle', 1),
#  ('Beric Dondarrion', 'Petyr Baelish', 1),
#  ('Lysa Arryn', 'Mord', 1),
#  ('Mord', 'Bronn', 1),
#  ('Mord', 'Vardis Egen', 1),
#  ('Mord', 'Robin Arryn', 1),
#  ('Mord', 'Catelyn Stark', 1),
#  ('Mord', 'Rodrik Cassel', 1),
#  ('Irri', 'Qotho', 3),
#  ('Qotho', 'Doreah', 3),
#  ('Jaime Lannister', 'Tywin Lannister', 30),
#  ('Petyr Baelish', 'Ros', 5),
#  ('Armeca', 'Petyr Baelish', 2),
#  ('Armeca', 'Ros', 2),
#  ('Maester Luwin', 'Osha', 9),
#  ('Jeor Mormont', 'Samwell Tarly', 17),
#  ('Cersei Lannister', 'Grand Maester Pycelle', 47),
#  ('Lord Varys', 'Barristan Selmy', 3),
#  ('Rakharo', 'Doreah', 7),
#  ('Jorah Mormont', 'Little Bird', 1),
#  ('Wine Merchant', 'Daenerys Targaryen', 3),
#  ('Wine Merchant', 'Doreah', 1),
#  ('Irri', 'Wine Merchant', 1),
#  ('Rakharo', 'Wine Merchant', 2),
#  ('Jorah Mormont', 'Wine Merchant', 3),
#  ('Jeor Mormont', 'Othell Yarwyck', 2),
#  ('Jon Snow', 'Othell Yarwyck', 19),
#  ('Maester Aemon', 'Samwell Tarly', 11),
#  ('Maester Aemon', 'Alliser Thorne', 7),
#  ('Maester Aemon', 'Othell Yarwyck', 6),
#  ('Othell Yarwyck', 'Pypar', 3),
#  ('Othell Yarwyck', 'Samwell Tarly', 11),
#  ('Othell Yarwyck', 'Grenn', 2),
#  ('Othell Yarwyck', 'Rast', 1),
#  ('Othell Yarwyck', 'Alliser Thorne', 16),
#  ('Jaremy Rykker', 'Jeor Mormont', 1),
#  ('Jaremy Rykker', 'Jon Snow', 1),
#  ('Jaremy Rykker', 'Pypar', 1),
#  ('Jaremy Rykker', 'Samwell Tarly', 1),
#  ('Jaremy Rykker', 'Grenn', 1),
#  ('Jaremy Rykker', 'Rast', 1),
#  ('Jaremy Rykker', 'Alliser Thorne', 1),
#  ('Jaremy Rykker', 'Maester Aemon', 1),
#  ('Jaremy Rykker', 'Othell Yarwyck', 1),
#  ('Tomard', 'Eddard Stark', 1),
#  ('Petyr Baelish', 'Tomard', 1),
#  ('Samwell Tarly', 'Ghost', 21),
#  ('Othell Yarwyck', 'Ghost', 4),
#  ('Khal Drogo', 'Wine Merchant', 2),
#  ('Qotho', 'Wine Merchant', 1),
#  ('Varly', 'Eddard Stark', 1),
#  ('Royal Steward', 'Varly', 1),
#  ('Robert Baratheon', 'Varly', 1),
#  ('Robert Baratheon', 'Royal Steward', 1),
#  ('Petyr Baelish', 'Royal Steward', 3),
#  ('Lord Varys', 'Royal Steward', 3),
#  ('Janos Slynt', 'Royal Steward', 3),
#  ('Lord Varys', 'Cersei Lannister', 40),
#  ('Lord Varys', 'Sandor Clegane', 19),
#  ('Joffrey Baratheon', 'Lord Varys', 14),
#  ('Joffrey Baratheon', 'Royal Steward', 2),
#  ('Barristan Selmy', 'Royal Steward', 2),
#  ('Royal Steward', 'Cersei Lannister', 2),
#  ('Royal Steward', 'Sandor Clegane', 2),
#  ('Janos Slynt', 'Joffrey Baratheon', 2),
#  ('Janos Slynt', 'Cersei Lannister', 4),
#  ('Janos Slynt', 'Barristan Selmy', 2),
#  ('Janos Slynt', 'Sandor Clegane', 2),
#  ('Arya Stark', 'Meryn Trant', 9),
#  ('Meryn Trant', 'Syrio Forel', 1),
#  ('Arya Stark', 'Red Keep Stableboy', 1),
#  ('Jeor Mormont', 'Othor', 2),
#  ('Jon Snow', 'Othor', 2),
#  ('Othor', 'Samwell Tarly', 1),
#  ('Jafer Flowers', 'Samwell Tarly', 1),
#  ('Jafer Flowers', 'Jeor Mormont', 1),
#  ('Jafer Flowers', 'Jon Snow', 1),
#  ('Jafer Flowers', 'Othor', 1),
#  ('Jafer Flowers', 'Othell Yarwyck', 1),
#  ('Othell Yarwyck', 'Othor', 1),
#  ('Lord Varys', 'Sansa Stark', 33),
#  ('Shagga', 'Tyrion Lannister', 4),
#  ('Shagga', 'Bronn', 4),
#  ('Othor', 'Ghost', 1),
#  ('Jeor Mormont', 'Ghost', 4),
#  ('Jorah Mormont', 'Mirri Maz Duur', 6),
#  ('Jorah Mormont', 'Mago', 2),
#  ('Irri', 'Mirri Maz Duur', 4),
#  ('Irri', 'Mago', 2),
#  ('Mirri Maz Duur', 'Daenerys Targaryen', 7),
#  ('Mirri Maz Duur', 'Rakharo', 5),
#  ('Mirri Maz Duur', 'Doreah', 3),
#  ('Mago', 'Daenerys Targaryen', 2),
#  ('Mago', 'Rakharo', 2),
#  ('Mago', 'Doreah', 2),
#  ('Mago', 'Mirri Maz Duur', 2),
#  ('Khal Drogo', 'Mago', 1),
#  ('Khal Drogo', 'Mirri Maz Duur', 4),
#  ('Mago', 'Qotho', 1),
#  ('Qotho', 'Rakharo', 3),
#  ('Mirri Maz Duur', 'Qotho', 2),
#  ('Greatjon Umber', 'Grey Wind', 1),
#  ('Bran Stark', 'Greatjon Umber', 1),
#  ('Theon Greyjoy', 'Greatjon Umber', 8),
#  ('Robb Stark', 'Greatjon Umber', 8),
#  ('Hodor', 'Osha', 25),
#  ('Catelyn Stark', 'Greatjon Umber', 7),
#  ('Rodrik Cassel', 'Greatjon Umber', 7),
#  ('Bronn', 'Timett', 4),
#  ('Shagga', 'Timett', 3),
#  ('Timett', 'Tyrion Lannister', 4),
#  ('Tyrion Lannister', 'Tywin Lannister', 47),
#  ('Bronn', 'Tywin Lannister', 3),
#  ('Shagga', 'Tywin Lannister', 1),
#  ('Kevan Lannister', 'Tyrion Lannister', 3),
#  ('Kevan Lannister', 'Tywin Lannister', 4),
#  ('Kevan Lannister', 'Bronn', 1),
#  ('Kevan Lannister', 'Shagga', 1),
#  ('Kevan Lannister', 'Timett', 1),
#  ('Kevan Lannister', 'Lannister Messenger', 1),
#  ('Timett', 'Tywin Lannister', 1),
#  ('Lannister Messenger', 'Tyrion Lannister', 1),
#  ('Lannister Messenger', 'Tywin Lannister', 1),
#  ('Lannister Messenger', 'Bronn', 1),
#  ('Lannister Messenger', 'Shagga', 1),
#  ('Lannister Messenger', 'Timett', 1),
#  ('Lannister Scout', 'Robb Stark', 1),
#  ('Lannister Scout', 'Theon Greyjoy', 1),
#  ('Lannister Scout', 'Greatjon Umber', 1),
#  ('Lannister Scout', 'Rodrik Cassel', 1),
#  ('Lannister Scout', 'Catelyn Stark', 1),
#  ('Joffrey Baratheon', 'Meryn Trant', 23),
#  ('Janos Slynt', 'Sansa Stark', 1),
#  ('Janos Slynt', 'Meryn Trant', 1),
#  ('Lord Varys', 'Meryn Trant', 2),
#  ('Barristan Selmy', 'Meryn Trant', 1),
#  ('Royal Steward', 'Grand Maester Pycelle', 1),
#  ('Meryn Trant', 'Sansa Stark', 15),
#  ('Meryn Trant', 'Cersei Lannister', 18),
#  ('Meryn Trant', 'Sandor Clegane', 11),
#  ('Meryn Trant', 'Grand Maester Pycelle', 3),
#  ('Meryn Trant', 'Petyr Baelish', 1),
#  ('Meryn Trant', 'Royal Steward', 1),
#  ('Walder Frey', 'Catelyn Stark', 13),
#  ('Joyeuse Erenford', 'Walder Frey', 9),
#  ('Joyeuse Erenford', 'Catelyn Stark', 10),
#  ('Joyeuse Erenford', 'Stevron Frey', 1),
#  ('Joyeuse Erenford', 'Ryger Rivers', 1),
#  ('Stevron Frey', 'Walder Frey', 1),
#  ('Stevron Frey', 'Catelyn Stark', 1),
#  ('Ryger Rivers', 'Walder Frey', 1),
#  ('Ryger Rivers', 'Catelyn Stark', 1),
#  ('Ryger Rivers', 'Stevron Frey', 1),
#  ('Shae', 'Tyrion Lannister', 31),
#  ('Shae', 'Bronn', 4),
#  ('Jaime Lannister', 'Greatjon Umber', 1),
#  ('Arya Stark', 'Grand Maester Pycelle', 1),
#  ('Yoren', 'Grand Maester Pycelle', 1),
#  ('Sansa Stark', 'Yoren', 2),
#  ('Petyr Baelish', 'Yoren', 1),
#  ('Cersei Lannister', 'Yoren', 1),
#  ('Joffrey Baratheon', 'Yoren', 1),
#  ('Lord Varys', 'Yoren', 2),
#  ('Sandor Clegane', 'Yoren', 2),
#  ('Ilyn Payne', 'Yoren', 2),
#  ('Ilyn Payne', 'Petyr Baelish', 1),
#  ('Ilyn Payne', 'Grand Maester Pycelle', 1),
#  ('Ilyn Payne', 'Lord Varys', 2),
#  ('Osha', 'Shaggydog', 8),
#  ('Osha', 'Rickon Stark', 23),
#  ('Rickon Stark', 'Shaggydog', 8),
#  ('Marillion', 'Sansa Stark', 1),
#  ('Marillion', 'Cersei Lannister', 1),
#  ('Marillion', 'Sandor Clegane', 1),
#  ('Marillion', 'Meryn Trant', 1),
#  ('Joffrey Baratheon', 'Marillion', 1),
#  ('Ilyn Payne', 'Marillion', 1),
#  ('Ilyn Payne', 'Meryn Trant', 1),
#  ('Meryn Trant', 'Eddard Stark', 1),
#  ('Meryn Trant', 'Septa Mordane', 1),
#  ('Rickard Karstark', 'Robb Stark', 7),
#  ('Rickard Karstark', 'Catelyn Stark', 6),
#  ('Rickard Karstark', 'Rodrik Cassel', 1),
#  ('Rickard Karstark', 'Theon Greyjoy', 1),
#  ('Rickard Karstark', 'Greatjon Umber', 1),
#  ('Jonos Bracken', 'Robb Stark', 1),
#  ('Jonos Bracken', 'Catelyn Stark', 1),
#  ('Jonos Bracken', 'Rodrik Cassel', 1),
#  ('Jonos Bracken', 'Theon Greyjoy', 1),
#  ('Jonos Bracken', 'Greatjon Umber', 1),
#  ('Jonos Bracken', 'Rickard Karstark', 1),
#  ('Lancel Lannister', 'Cersei Lannister', 9),
#  ('Kevan Lannister', 'Leo Lefford', 1),
#  ('Leo Lefford', 'Tywin Lannister', 1),
#  ('Leo Lefford', 'Tyrion Lannister', 1),
#  ('Addam Marbrand', 'Tywin Lannister', 1),
#  ('Addam Marbrand', 'Kevan Lannister', 1),
#  ('Addam Marbrand', 'Tyrion Lannister', 1),
#  ('Addam Marbrand', 'Leo Lefford', 1),
#  ('Mirri Maz Duur', 'Rhaego', 1),
#  ('Ros', 'Grand Maester Pycelle', 1),
#  ('Arya Stark', 'Lommy Greenhands', 6),
#  ('Arya Stark', 'Gendry', 50),
#  ('Hot Pie', 'Arya Stark', 23),
#  ('Hot Pie', 'Lommy Greenhands', 6),
#  ('Hot Pie', 'Gendry', 22),
#  ('Hot Pie', 'Yoren', 3),
#  ('Lommy Greenhands', 'Gendry', 6),
#  ('Lommy Greenhands', 'Yoren', 3),
#  ('Yoren', 'Gendry', 6),
#  ('Rakharo', 'Drogon', 3),
#  ('Rakharo', 'Rhaegal', 2),
#  ('Rakharo', 'Viserion', 2),
#  ('Mirri Maz Duur', 'Drogon', 1),
#  ('Mirri Maz Duur', 'Rhaegal', 1),
#  ('Mirri Maz Duur', 'Viserion', 1),
#  ('Joffrey Baratheon', 'Dontos Hollard', 4),
#  ('Joffrey Baratheon', 'Bronn', 3),
#  ('Tommen Baratheon', 'Dontos Hollard', 2),
#  ('Myrcella Baratheon', 'Dontos Hollard', 1),
#  ('Myrcella Baratheon', 'Bronn', 6),
#  ('Sansa Stark', 'Dontos Hollard', 11),
#  ('Sansa Stark', 'Tyrion Lannister', 80),
#  ('Sansa Stark', 'Bronn', 3),
#  ('Sandor Clegane', 'Dontos Hollard', 1),
#  ('Sandor Clegane', 'Bronn', 7),
#  ('Meryn Trant', 'Tommen Baratheon', 7),
#  ('Meryn Trant', 'Myrcella Baratheon', 1),
#  ('Meryn Trant', 'Dontos Hollard', 2),
#  ('Meryn Trant', 'Tyrion Lannister', 13),
#  ('Meryn Trant', 'Bronn', 3),
#  ('Tyrion Lannister', 'Dontos Hollard', 4),
#  ('Bronn', 'Tommen Baratheon', 1),
#  ('Bronn', 'Dontos Hollard', 1),
#  ('Lord Varys', 'Tyrion Lannister', 141),
#  ('Petyr Baelish', 'Tyrion Lannister', 8),
#  ('Janos Slynt', 'Tyrion Lannister', 4),
#  ('Tyrion Lannister', 'Grand Maester Pycelle', 24),
#  ('Lord Portan', 'Bran Stark', 1),
#  ('Lord Portan', 'Maester Luwin', 1),
#  ('Jorah Mormont', 'Kovarro', 11),
#  ('Kovarro', 'Daenerys Targaryen', 15),
#  ('Kovarro', 'Drogon', 3),
#  ('Kovarro', 'Doreah', 4),
#  ('Kovarro', 'Rakharo', 1),
#  ('Jon Snow', 'Eddison Tollett', 81),
#  ('Samwell Tarly', 'Eddison Tollett', 45),
#  ('Eddison Tollett', 'Grenn', 41),
#  ('Jeor Mormont', 'Craster', 8),
#  ('Jeor Mormont', 'Gilly', 1),
#  ('Craster', 'Gilly', 1),
#  ('Jon Snow', 'Craster', 4),
#  ('Jon Snow', 'Gilly', 12),
#  ('Melisandre', 'Davos Seaworth', 38),
#  ('Melisandre', 'Stannis Baratheon', 32),
#  ('Melisandre', 'Selyse Baratheon', 11),
#  ('Maester Cressen', 'Melisandre', 2),
#  ('Maester Cressen', 'Davos Seaworth', 3),
#  ('Maester Cressen', 'Matthos Seaworth', 2),
#  ('Maester Cressen', 'Stannis Baratheon', 2),
#  ('Maester Cressen', 'Selyse Baratheon', 1),
#  ('Matthos Seaworth', 'Melisandre', 3),
#  ('Matthos Seaworth', 'Davos Seaworth', 12),
#  ('Matthos Seaworth', 'Stannis Baratheon', 5),
#  ('Matthos Seaworth', 'Selyse Baratheon', 1),
#  ('Stannis Baratheon', 'Davos Seaworth', 35),
#  ('Selyse Baratheon', 'Davos Seaworth', 8),
#  ('Selyse Baratheon', 'Stannis Baratheon', 12),
#  ('Jaime Lannister', 'Grey Wind', 1),
#  ('Robb Stark', 'Alton Lannister', 2),
#  ('Rodrik Cassel', 'Alton Lannister', 1),
#  ('Theon Greyjoy', 'Alton Lannister', 1),
#  ('Ros', 'Daisy', 3),
#  ('Armeca', 'Daisy', 1),
#  ('Janos Slynt', 'Ros', 1),
#  ('Janos Slynt', 'Daisy', 1),
#  ('Janos Slynt', 'Mhaegen', 1),
#  ('Mhaegen', 'Ros', 1),
#  ('Mhaegen', 'Daisy', 1),
#  ('Janos Slynt', 'Tobho Mott', 1),
#  ('Arya Stark', 'Rorge', 3),
#  ('Arya Stark', 'Biter', 3),
#  ("Jaqen H'ghar", 'Arya Stark', 34),
#  ("Jaqen H'ghar", 'Rorge', 1),
#  ("Jaqen H'ghar", 'Biter', 1),
#  ("Jaqen H'ghar", 'Gendry', 4),
#  ('Rorge', 'Gendry', 1),
#  ('Biter', 'Rorge', 2),
#  ('Biter', 'Gendry', 1),
#  ('Arya Stark', 'Goldcloak', 1),
#  ('Gendry', 'Goldcloak', 1),
#  ('Yoren', 'Goldcloak', 1),
#  ('Lord Varys', 'Shae', 4),
#  ('Cersei Lannister', 'Alton Lannister', 1),
#  ('Alton Lannister', 'Grand Maester Pycelle', 1),
#  ('Tyrion Lannister', 'Alton Lannister', 1),
#  ('Lord Varys', 'Alton Lannister', 1),
#  ('Petyr Baelish', 'Alton Lannister', 1),
#  ('Samwell Tarly', 'Gilly', 62),
#  ('Ghost', 'Gilly', 4),
#  ('Podrick Payne', 'Tyrion Lannister', 75),
#  ('Janos Slynt', 'Podrick Payne', 1),
#  ('Janos Slynt', 'Bronn', 1),
#  ('Lordsport Dockhand', 'Theon Greyjoy', 1),
#  ('Theon Greyjoy', 'Yara Greyjoy', 33),
#  ('Balon Greyjoy', 'Theon Greyjoy', 4),
#  ('Balon Greyjoy', 'Yara Greyjoy', 7),
#  ('Matthos Seaworth', 'Salladhor Saan', 1),
#  ('Salladhor Saan', 'Davos Seaworth', 3),
#  ('Jon Snow', 'White Walker', 10),
#  ('White Walker', 'Craster', 1),
#  ('Renly Baratheon', 'Brienne of Tarth', 6),
#  ('Renly Baratheon', 'Catelyn Stark', 4),
#  ('Renly Baratheon', 'Colen of Greenpools', 1),
#  ('Margaery Tyrell', 'Renly Baratheon', 3),
#  ('Margaery Tyrell', 'Brienne of Tarth', 5),
#  ('Margaery Tyrell', 'Catelyn Stark', 1),
#  ('Margaery Tyrell', 'Colen of Greenpools', 1),
#  ('Brienne of Tarth', 'Catelyn Stark', 13),
#  ('Brienne of Tarth', 'Colen of Greenpools', 1),
#  ('Catelyn Stark', 'Colen of Greenpools', 1),
#  ('Loras Tyrell', 'Margaery Tyrell', 37),
#  ('Loras Tyrell', 'Brienne of Tarth', 2),
#  ('Loras Tyrell', 'Catelyn Stark', 2),
#  ('Loras Tyrell', 'Colen of Greenpools', 1),
#  ('Sansa Stark', 'Shae', 33),
#  ('Balon Greyjoy', 'Drowned Priest', 1),
#  ('Yara Greyjoy', 'Drowned Priest', 1),
#  ('Theon Greyjoy', 'Drowned Priest', 1),
#  ('Petyr Baelish', 'Bronn', 1),
#  ('Daisy', 'Grand Maester Pycelle', 1),
#  ('Bronn', 'Grand Maester Pycelle', 2),
#  ('Bronn', 'Daisy', 1),
#  ('Tyrion Lannister', 'Daisy', 1),
#  ('Timett', 'Grand Maester Pycelle', 1),
#  ('Timett', 'Daisy', 1),
#  ('Yoren', 'Amory Lorch', 2),
#  ('Arya Stark', 'Amory Lorch', 5),
#  ('Arya Stark', 'Polliver', 8),
#  ('Gendry', 'Amory Lorch', 3),
#  ('Polliver', 'Yoren', 1),
#  ('Polliver', 'Amory Lorch', 1),
#  ('Polliver', 'Gendry', 2),
#  ('Hot Pie', "Jaqen H'ghar", 3),
#  ('Hot Pie', 'Polliver', 1),
#  ('Lommy Greenhands', 'Polliver', 1),
#  ("Jaqen H'ghar", 'Lommy Greenhands', 1),
#  ("Jaqen H'ghar", 'Polliver', 1),
#  ('Hot Pie', 'Amory Lorch', 2),
#  ('Lommy Greenhands', 'Amory Lorch', 1),
#  ('Robb Stark', 'Roose Bolton', 20),
#  ...]

# %% [markdown]
# This view implys that the number of two distinct characters showing in same seasonNum, episodeNum,sceneNum

# %% [markdown]
# ## Programming

# %% [markdown]
# ### Data Processing and Cleansing
#
# #### Task
#
# - The ```scene``` information in ```episodes.json``` complements and extend some of the information about character interactions and relationships. An example is:
#
# ```
#             {
#                "sceneStart":"0:50:24",
#                "sceneEnd":"0:55:54",
#                "location":"The Crownlands",
#                "subLocation":"King's Landing",
#                "characters":[
#                   {
#                      "name":"Arya Stark",
#                      "weapon":[
#                         {"action":"has", "name":"Needle"}
#                      ]
#                   },
#                   {
#                      "name":"Eddard Stark",
#                      "title":"Hand",
#                      "alive":false,
#                      "mannerOfDeath":"Decapitation",
#                      "killedBy":[
#                         "Ilyn Payne"
#                      ]
#                   },
#                   {"name":"Yoren"},
#                   {"name":"Sansa Stark"},
#                   {"name":"Petyr Baelish"},
#                   {"name":"Cersei Lannister"},
#                   {"name":"Joffrey Baratheon", "title":"King"},
#                   {"name":"Grand Maester Pycelle"},
#                   {"name":"Lord Varys"},
#                   {"name":"Sandor Clegane"},
#                   {
#                      "name":"Ilyn Payne",
#                      "weapon":[
#                         {"action":"has", "name":"Ice"}
#                      ]
#                   }
#                ]
#             }
#          ]
# ```
#
#
# - A little data processing determines that the top-level elements of a ```character``` in a scene are:
#
# ```Top level keys in characters in scenes are:
# 	 sex
# 	 name
# 	 weapon
# 	 born
# 	 married
# 	 killedBy
# 	 mannerOfDeath
# 	 title
# 	 alive
# ```

# %% [markdown]
# - Your data processing and cleanse tasks is to create a table of the form:
#     - ```seasonNum```
#     - ```episodeNum```
#     - ```sceneNo```
#     - ```character_id_1```
#     - ```action```
#     - ```character_id_2```
#
#
# - You can get access to information that maps ```characterName``` to ```character_id``` using the following code.

# %%
import pymysql
cloud_conn = pymysql.connect(
    host="columbia8013.cqgsme1nmjms.us-east-1.rds.amazonaws.com",
    user="gotuser",
    password="gotusergotuser",
    db="W4111GoTSolutionClean",
    cursorclass=pymysql.cursors.DictCursor)

# %%
def get_character_info(c_name):
    
    sql = "select * from characters where characterName=%s"
    cur = cloud_conn.cursor()
    res = cur.execute(sql, (c_name))
    res = cur.fetchall()
    return res

# %%
get_character_info("Sansa Stark")
# Out:
# [{'id': 300,
#   'characterName': 'Sansa Stark',
#   'characterLink': '/character/ch0158137/',
#   'actorName': 'Sophie Turner',
#   'actorLink': '/name/nm3849842/',
#   'character_id': 'CH_300',
#   'royal': 1,
#   'characterImageThumb': 'https://images-na.ssl-images-amazon.com/images/M/MV5BNjAwMjE2NDExNF5BMl5BanBnXkFtZTcwODAwODg4OQ@@._V1._SX100_SY140_.jpg',
#   'characterImageFull': 'https://images-na.ssl-images-amazon.com/images/M/MV5BNjAwMjE2NDExNF5BMl5BanBnXkFtZTcwODAwODg4OQ@@._V1_SY1000_CR0,0,806,1000_AL_.jpg',
#   'nickname': None,
#   'kingsguard': 0}]

# %% [markdown]
# #### Answer

# %% [markdown]
# <u>Table Definition</u>

# %%
# %%sql
# create table answers as
# select seasonNum,episodeNum,sceneNo,a.character_id as character_id_1,action,b.character_id as character_id_2
# from events,characters a,characters b
# where events.name1=a.characterName and events.name2=b.characterName;
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 312 rows affected.
# []

# %% [markdown]
# <u>Sample Query</u>

# %%
# %%sql
# select *
# from answers
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 312 rows affected.
# [(6, 5, 28, 'CH_65', 'killedBy', 'CH_2'),
#  (2, 3, 28, 'CH_380', 'killedBy', 'CH_8'),
#  (1, 7, 3, 'CH_293', 'sex', 'CH_12'),
#  (6, 10, 75, 'CH_25', 'killedBy', 'CH_15'),
#  (8, 2, 56, 'CH_70', 'sex', 'CH_15'),
#  (6, 10, 75, 'CH_179', 'killedBy', 'CH_15'),
#  (5, 10, 35, 'CH_211', 'killedBy', 'CH_15'),
#  (7, 7, 52, 'CH_257', 'killedBy', 'CH_15'),
#  (4, 1, 55, 'CH_259', 'killedBy', 'CH_15'),
#  (1, 8, 9, 'CH_274', 'killedBy', 'CH_15'),
#  (4, 7, 6, 'CH_292', 'killedBy', 'CH_15'),
#  (8, 3, 279, 'CH_332', 'killedBy', 'CH_15'),
#  (6, 8, 51, 'CH_334', 'killedBy', 'CH_15'),
#  (8, 3, 280, 'CH_354', 'killedBy', 'CH_15'),
#  (6, 10, 76, 'CH_357', 'killedBy', 'CH_15'),
#  (8, 3, 279, 'CH_362', 'killedBy', 'CH_15'),
#  (8, 3, 279, 'CH_363', 'killedBy', 'CH_15'),
#  (8, 3, 279, 'CH_364', 'killedBy', 'CH_15'),
#  (3, 9, 71, 'CH_36', 'killedBy', 'CH_25'),
#  (8, 4, 46, 'CH_113', 'sex', 'CH_31'),
#  (5, 10, 26, 'CH_316', 'killedBy', 'CH_31'),
#  (5, 4, 30, 'CH_158', 'killedBy', 'CH_32'),
#  (8, 1, 39, 'CH_198', 'sex', 'CH_32'),
#  (2, 9, 45, 'CH_204', 'killedBy', 'CH_32'),
#  (1, 6, 15, 'CH_352', 'killedBy', 'CH_32'),
#  (3, 9, 71, 'CH_127', 'killedBy', 'CH_36'),
#  (8, 1, 44, 'CH_65', 'sex', 'CH_38'),
#  (6, 10, 49, 'CH_100', 'killedBy', 'CH_38'),
#  (1, 1, 36, 'CH_113', 'sex', 'CH_38'),
#  (4, 3, 18, 'CH_113', 'sex', 'CH_38'),
#  (4, 10, 13, 'CH_113', 'sex', 'CH_38'),
#  (6, 6, 56, 'CH_113', 'sex', 'CH_38'),
#  (7, 3, 19, 'CH_113', 'sex', 'CH_38'),
#  (6, 10, 49, 'CH_132', 'killedBy', 'CH_38'),
#  (1, 10, 12, 'CH_152', 'sex', 'CH_38'),
#  (6, 10, 48, 'CH_152', 'killedBy', 'CH_38'),
#  (6, 10, 49, 'CH_174', 'killedBy', 'CH_38'),
#  (6, 10, 49, 'CH_185', 'killedBy', 'CH_38'),
#  (6, 10, 49, 'CH_199', 'killedBy', 'CH_38'),
#  (7, 3, 17, 'CH_348', 'killedBy', 'CH_38'),
#  (6, 4, 18, 'CH_4', 'killedBy', 'CH_43'),
#  (4, 7, 12, 'CH_44', 'sex', 'CH_43'),
#  (5, 1, 34, 'CH_44', 'sex', 'CH_43'),
#  (5, 7, 24, 'CH_44', 'sex', 'CH_43'),
#  (3, 8, 43, 'CH_210', 'killedBy', 'CH_43'),
#  (5, 2, 42, 'CH_218', 'killedBy', 'CH_43'),
#  (3, 8, 43, 'CH_260', 'killedBy', 'CH_43'),
#  (4, 7, 12, 'CH_43', 'sex', 'CH_44'),
#  (5, 1, 34, 'CH_43', 'sex', 'CH_44'),
#  (5, 7, 24, 'CH_43', 'sex', 'CH_44'),
#  (7, 5, 6, 'CH_48', 'killedBy', 'CH_44'),
#  (2, 10, 38, 'CH_53', 'killedBy', 'CH_44'),
#  (6, 4, 39, 'CH_54', 'killedBy', 'CH_44'),
#  (6, 4, 39, 'CH_55', 'killedBy', 'CH_44'),
#  (5, 5, 4, 'CH_79', 'killedBy', 'CH_44'),
#  (7, 7, 68, 'CH_123', 'sex', 'CH_44'),
#  (1, 1, 33, 'CH_133', 'married', 'CH_44'),
#  (1, 1, 34, 'CH_133', 'sex', 'CH_44'),
#  (1, 2, 11, 'CH_133', 'sex', 'CH_44'),
#  (1, 2, 20, 'CH_133', 'sex', 'CH_44'),
#  (1, 3, 23, 'CH_133', 'sex', 'CH_44'),
#  (1, 10, 22, 'CH_133', 'killedBy', 'CH_44'),
#  (6, 4, 39, 'CH_134', 'killedBy', 'CH_44'),
#  (6, 4, 39, 'CH_135', 'killedBy', 'CH_44'),
#  (3, 4, 44, 'CH_148', 'killedBy', 'CH_44'),
#  (8, 5, 14, 'CH_177', 'killedBy', 'CH_44'),
#  (1, 10, 31, 'CH_215', 'killedBy', 'CH_44'),
#  (2, 10, 34, 'CH_261', 'killedBy', 'CH_44'),
#  (7, 5, 6, 'CH_270', 'killedBy', 'CH_44'),
#  (2, 10, 38, 'CH_375', 'killedBy', 'CH_44'),
#  (2, 3, 24, 'CH_78', 'sex', 'CH_46'),
#  (2, 4, 12, 'CH_293', 'sex', 'CH_46'),
#  (2, 6, 46, 'CH_109', 'killedBy', 'CH_53'),
#  (1, 4, 8, 'CH_355', 'sex', 'CH_53'),
#  (2, 10, 37, 'CH_375', 'sex', 'CH_53'),
#  (1, 2, 30, 'CH_150', 'killedBy', 'CH_59'),
#  (1, 1, 15, 'CH_368', 'killedBy', 'CH_59'),
#  (3, 9, 37, 'CH_294', 'married', 'CH_61'),
#  (6, 1, 26, 'CH_52', 'killedBy', 'CH_62'),
#  (4, 3, 33, 'CH_198', 'sex', 'CH_62'),
#  (5, 10, 40, 'CH_229', 'killedBy', 'CH_62'),
#  (4, 3, 33, 'CH_245', 'sex', 'CH_62'),
#  (4, 3, 33, 'CH_250', 'sex', 'CH_62'),
#  (6, 2, 39, 'CH_17', 'killedBy', 'CH_65'),
#  (8, 1, 44, 'CH_38', 'sex', 'CH_65'),
#  (7, 2, 49, 'CH_243', 'killedBy', 'CH_65'),
#  (7, 2, 48, 'CH_244', 'killedBy', 'CH_65'),
#  (8, 4, 71, 'CH_278', 'killedBy', 'CH_65'),
#  (8, 2, 56, 'CH_15', 'sex', 'CH_70'),
#  (3, 8, 20, 'CH_208', 'sex', 'CH_70'),
#  (4, 5, 48, 'CH_271', 'killedBy', 'CH_72'),
#  (5, 7, 21, 'CH_298', 'sex', 'CH_73'),
#  (2, 3, 24, 'CH_46', 'sex', 'CH_78'),
#  (6, 10, 9, 'CH_198', 'sex', 'CH_78'),
#  (1, 10, 23, 'CH_293', 'sex', 'CH_78'),
#  (1, 4, 26, 'CH_106', 'killedBy', 'CH_87'),
#  (8, 4, 111, 'CH_216', 'killedBy', 'CH_87'),
#  (4, 8, 33, 'CH_245', 'killedBy', 'CH_87'),
#  (8, 5, 178, 'CH_267', 'killedBy', 'CH_87'),
#  (4, 9, 85, 'CH_190', 'killedBy', 'CH_89'),
#  (8, 5, 78, 'CH_96', 'killedBy', 'CH_91'),
#  (7, 2, 16, 'CH_216', 'sex', 'CH_91'),
#  (6, 9, 12, 'CH_273', 'killedBy', 'CH_91'),
#  (4, 5, 40, 'CH_171', 'killedBy', 'CH_102'),
#  (6, 3, 7, 'CH_14', 'killedBy', 'CH_105'),
#  (1, 9, 25, 'CH_59', 'killedBy', 'CH_108'),
#  (2, 7, 26, 'CH_6', 'killedBy', 'CH_113'),
#  (8, 4, 46, 'CH_31', 'sex', 'CH_113'),
#  (1, 1, 36, 'CH_38', 'sex', 'CH_113'),
#  (4, 3, 18, 'CH_38', 'sex', 'CH_113'),
#  (4, 10, 13, 'CH_38', 'sex', 'CH_113'),
#  (6, 6, 56, 'CH_38', 'sex', 'CH_113'),
#  (7, 3, 19, 'CH_38', 'sex', 'CH_113'),
#  (8, 5, 173, 'CH_65', 'killedBy', 'CH_113'),
#  (1, 5, 28, 'CH_126', 'killedBy', 'CH_113'),
#  (7, 3, 50, 'CH_248', 'killedBy', 'CH_113'),
#  (2, 6, 33, 'CH_8', 'killedBy', 'CH_115'),
#  (5, 10, 37, 'CH_115', 'killedBy', 'CH_115'),
#  (2, 5, 38, 'CH_333', 'killedBy', 'CH_115'),
#  (3, 1, 6, 'CH_362', 'killedBy', 'CH_118'),
#  (3, 1, 6, 'CH_363', 'killedBy', 'CH_118'),
#  (3, 1, 6, 'CH_364', 'killedBy', 'CH_118'),
#  (4, 2, 45, 'CH_199', 'married', 'CH_120'),
#  (3, 6, 23, 'CH_293', 'killedBy', 'CH_120'),
#  (6, 3, 35, 'CH_5', 'killedBy', 'CH_123'),
#  (6, 3, 35, 'CH_27', 'killedBy', 'CH_123'),
#  (7, 7, 68, 'CH_44', 'sex', 'CH_123'),
#  (8, 6, 40, 'CH_44', 'killedBy', 'CH_123'),
#  (5, 3, 28, 'CH_114', 'killedBy', 'CH_123'),
#  (4, 5, 45, 'CH_128', 'killedBy', 'CH_123'),
#  (5, 1, 46, 'CH_195', 'killedBy', 'CH_123'),
#  (6, 3, 35, 'CH_249', 'killedBy', 'CH_123'),
#  (3, 9, 29, 'CH_251', 'killedBy', 'CH_123'),
#  (6, 3, 35, 'CH_254', 'killedBy', 'CH_123'),
#  (1, 8, 21, 'CH_255', 'killedBy', 'CH_123'),
#  (2, 10, 35, 'CH_264', 'killedBy', 'CH_123'),
#  (4, 9, 75, 'CH_325', 'killedBy', 'CH_123'),
#  (5, 8, 45, 'CH_362', 'killedBy', 'CH_123'),
#  (7, 6, 27, 'CH_362', 'killedBy', 'CH_123'),
#  (5, 8, 45, 'CH_363', 'killedBy', 'CH_123'),
#  (7, 6, 27, 'CH_363', 'killedBy', 'CH_123'),
#  (5, 8, 45, 'CH_364', 'killedBy', 'CH_123'),
#  (7, 6, 27, 'CH_364', 'killedBy', 'CH_123'),
#  (3, 5, 5, 'CH_378', 'sex', 'CH_123'),
#  (1, 9, 15, 'CH_265', 'killedBy', 'CH_125'),
#  (3, 4, 33, 'CH_42', 'killedBy', 'CH_128'),
#  (1, 1, 33, 'CH_44', 'married', 'CH_133'),
#  (1, 1, 34, 'CH_44', 'sex', 'CH_133'),
#  (1, 2, 11, 'CH_44', 'sex', 'CH_133'),
#  (1, 2, 20, 'CH_44', 'sex', 'CH_133'),
#  (1, 3, 23, 'CH_44', 'sex', 'CH_133'),
#  (1, 8, 23, 'CH_192', 'killedBy', 'CH_133'),
#  (1, 6, 19, 'CH_355', 'killedBy', 'CH_133'),
#  (1, 10, 12, 'CH_38', 'sex', 'CH_152'),
#  (6, 7, 46, 'CH_33', 'killedBy', 'CH_160'),
#  (3, 5, 34, 'CH_250', 'sex', 'CH_174'),
#  (5, 1, 27, 'CH_250', 'sex', 'CH_174'),
#  (1, 5, 24, 'CH_277', 'sex', 'CH_174'),
#  (2, 3, 18, 'CH_277', 'sex', 'CH_174'),
#  (3, 9, 68, 'CH_328', 'killedBy', 'CH_179'),
#  (7, 7, 63, 'CH_279', 'married', 'CH_183'),
#  (1, 1, 17, 'CH_122', 'killedBy', 'CH_184'),
#  (4, 5, 16, 'CH_257', 'sex', 'CH_184'),
#  (2, 1, 18, 'CH_187', 'killedBy', 'CH_187'),
#  (4, 9, 85, 'CH_89', 'killedBy', 'CH_190'),
#  (8, 1, 39, 'CH_32', 'sex', 'CH_198'),
#  (6, 10, 9, 'CH_78', 'sex', 'CH_198'),
#  (4, 2, 45, 'CH_120', 'married', 'CH_199'),
#  (2, 3, 7, 'CH_277', 'married', 'CH_199'),
#  (5, 3, 6, 'CH_344', 'married', 'CH_199'),
#  (5, 3, 7, 'CH_344', 'sex', 'CH_199'),
#  (4, 10, 26, 'CH_121', 'killedBy', 'CH_205'),
#  (6, 5, 59, 'CH_362', 'killedBy', 'CH_205'),
#  (6, 5, 59, 'CH_363', 'killedBy', 'CH_205'),
#  (6, 5, 59, 'CH_364', 'killedBy', 'CH_205'),
#  (3, 8, 20, 'CH_70', 'sex', 'CH_208'),
#  (2, 5, 1, 'CH_277', 'killedBy', 'CH_208'),
#  (5, 9, 39, 'CH_312', 'killedBy', 'CH_208'),
#  (2, 2, 29, 'CH_316', 'sex', 'CH_208'),
#  (1, 8, 6, 'CH_327', 'killedBy', 'CH_211'),
#  (7, 2, 16, 'CH_91', 'sex', 'CH_216'),
#  (4, 6, 7, 'CH_269', 'sex', 'CH_228'),
#  (4, 6, 9, 'CH_269', 'sex', 'CH_228'),
#  (4, 6, 11, 'CH_269', 'sex', 'CH_228'),
#  (4, 6, 13, 'CH_269', 'sex', 'CH_228'),
#  (5, 5, 17, 'CH_269', 'sex', 'CH_228'),
#  (3, 7, 34, 'CH_336', 'sex', 'CH_228'),
#  (5, 4, 33, 'CH_209', 'killedBy', 'CH_244'),
#  (6, 1, 27, 'CH_346', 'killedBy', 'CH_244'),
#  (4, 2, 81, 'CH_120', 'killedBy', 'CH_248'),
#  (5, 10, 64, 'CH_123', 'killedBy', 'CH_249'),
#  (4, 9, 77, 'CH_378', 'killedBy', 'CH_249'),
#  (4, 3, 33, 'CH_62', 'sex', 'CH_250'),
#  (3, 5, 34, 'CH_174', 'sex', 'CH_250'),
#  (5, 1, 27, 'CH_174', 'sex', 'CH_250'),
#  (2, 6, 43, 'CH_56', 'killedBy', 'CH_253'),
#  (2, 10, 28, 'CH_188', 'killedBy', 'CH_253'),
#  (2, 6, 40, 'CH_336', 'sex', 'CH_253'),
#  (4, 3, 8, 'CH_51', 'killedBy', 'CH_257'),
#  (4, 5, 16, 'CH_184', 'sex', 'CH_257'),
#  (4, 7, 27, 'CH_184', 'killedBy', 'CH_257'),
#  (3, 3, 32, 'CH_130', 'sex', 'CH_258'),
#  (2, 9, 115, 'CH_196', 'killedBy', 'CH_258'),
#  (3, 3, 32, 'CH_198', 'sex', 'CH_258'),
#  (2, 3, 29, 'CH_173', 'killedBy', 'CH_259'),
#  (2, 7, 29, 'CH_313', 'killedBy', 'CH_261'),
#  (2, 7, 29, 'CH_315', 'killedBy', 'CH_261'),
#  (4, 6, 7, 'CH_228', 'sex', 'CH_269'),
#  (4, 6, 9, 'CH_228', 'sex', 'CH_269'),
#  (4, 6, 11, 'CH_228', 'sex', 'CH_269'),
#  (4, 6, 13, 'CH_228', 'sex', 'CH_269'),
#  (5, 5, 17, 'CH_228', 'sex', 'CH_269'),
#  (6, 4, 30, 'CH_253', 'killedBy', 'CH_269'),
#  (6, 9, 36, 'CH_285', 'killedBy', 'CH_269'),
#  (6, 2, 33, 'CH_291', 'killedBy', 'CH_269'),
#  (5, 6, 38, 'CH_300', 'married', 'CH_269'),
#  (5, 6, 39, 'CH_300', 'sex', 'CH_269'),
#  (4, 2, 6, 'CH_356', 'married', 'CH_269'),
#  (6, 2, 34, 'CH_356', 'killedBy', 'CH_269'),
#  (6, 9, 63, 'CH_373', 'killedBy', 'CH_269'),
#  (3, 4, 36, 'CH_118', 'killedBy', 'CH_271'),
#  (1, 5, 24, 'CH_174', 'sex', 'CH_277'),
#  (2, 3, 18, 'CH_174', 'sex', 'CH_277'),
#  (2, 3, 7, 'CH_199', 'married', 'CH_277'),
#  (7, 7, 63, 'CH_183', 'married', 'CH_279'),
#  (3, 5, 14, 'CH_202', 'killedBy', 'CH_283'),
#  (3, 5, 14, 'CH_369', 'killedBy', 'CH_283'),
#  (3, 5, 18, 'CH_283', 'killedBy', 'CH_286'),
#  (2, 8, 31, 'CH_328', 'sex', 'CH_286'),
#  (2, 10, 17, 'CH_328', 'married', 'CH_286'),
#  (3, 7, 6, 'CH_328', 'sex', 'CH_286'),
#  (1, 6, 6, 'CH_358', 'killedBy', 'CH_286'),
#  (3, 9, 70, 'CH_286', 'killedBy', 'CH_291'),
#  (1, 7, 3, 'CH_12', 'sex', 'CH_293'),
#  (2, 4, 12, 'CH_46', 'sex', 'CH_293'),
#  (1, 10, 23, 'CH_78', 'sex', 'CH_293'),
#  (1, 5, 8, 'CH_336', 'sex', 'CH_293'),
#  (1, 1, 23, 'CH_349', 'sex', 'CH_293'),
#  (3, 9, 37, 'CH_61', 'married', 'CH_294'),
#  (5, 7, 21, 'CH_73', 'sex', 'CH_298'),
#  (4, 9, 53, 'CH_335', 'killedBy', 'CH_298'),
#  (3, 8, 49, 'CH_362', 'killedBy', 'CH_298'),
#  (3, 8, 49, 'CH_363', 'killedBy', 'CH_298'),
#  (3, 8, 49, 'CH_364', 'killedBy', 'CH_298'),
#  (3, 5, 1, 'CH_21', 'killedBy', 'CH_299'),
#  (4, 7, 5, 'CH_23', 'killedBy', 'CH_299'),
#  (6, 8, 7, 'CH_69', 'killedBy', 'CH_299'),
#  (8, 5, 204, 'CH_87', 'killedBy', 'CH_299'),
#  (2, 6, 24, 'CH_140', 'killedBy', 'CH_299'),
#  (2, 6, 24, 'CH_141', 'killedBy', 'CH_299'),
#  (2, 6, 24, 'CH_142', 'killedBy', 'CH_299'),
#  (6, 8, 46, 'CH_160', 'killedBy', 'CH_299'),
#  (1, 2, 26, 'CH_227', 'killedBy', 'CH_299'),
#  (8, 5, 204, 'CH_299', 'killedBy', 'CH_299'),
#  (5, 6, 38, 'CH_269', 'married', 'CH_300'),
#  (5, 6, 39, 'CH_269', 'sex', 'CH_300'),
#  (6, 9, 71, 'CH_269', 'killedBy', 'CH_300'),
#  (3, 8, 19, 'CH_349', 'married', 'CH_300'),
#  (5, 10, 5, 'CH_301', 'killedBy', 'CH_301'),
#  (1, 9, 14, 'CH_349', 'sex', 'CH_309'),
#  (1, 9, 16, 'CH_349', 'sex', 'CH_309'),
#  (1, 10, 19, 'CH_349', 'sex', 'CH_309'),
#  (2, 9, 5, 'CH_349', 'sex', 'CH_309'),
#  (3, 2, 36, 'CH_349', 'sex', 'CH_309'),
#  (6, 3, 32, 'CH_311', 'killedBy', 'CH_314'),
#  (2, 2, 29, 'CH_208', 'sex', 'CH_316'),
#  (4, 8, 3, 'CH_131', 'killedBy', 'CH_325'),
#  (1, 2, 13, 'CH_37', 'killedBy', 'CH_326'),
#  (2, 8, 31, 'CH_286', 'sex', 'CH_328'),
#  (2, 10, 17, 'CH_286', 'married', 'CH_328'),
#  (3, 7, 6, 'CH_286', 'sex', 'CH_328'),
#  (8, 1, 83, 'CH_230', 'killedBy', 'CH_332'),
#  (8, 3, 272, 'CH_336', 'killedBy', 'CH_332'),
#  (6, 5, 67, 'CH_339', 'killedBy', 'CH_332'),
#  (7, 6, 48, 'CH_354', 'killedBy', 'CH_332'),
#  (6, 8, 50, 'CH_151', 'killedBy', 'CH_334'),
#  (3, 7, 34, 'CH_228', 'sex', 'CH_336'),
#  (5, 10, 30, 'CH_228', 'killedBy', 'CH_336'),
#  (2, 6, 40, 'CH_253', 'sex', 'CH_336'),
#  (2, 6, 6, 'CH_290', 'killedBy', 'CH_336'),
#  (1, 5, 8, 'CH_293', 'sex', 'CH_336'),
#  (1, 6, 6, 'CH_324', 'killedBy', 'CH_336'),
#  (5, 3, 6, 'CH_199', 'married', 'CH_344'),
#  (5, 3, 7, 'CH_199', 'sex', 'CH_344'),
#  (6, 10, 55, 'CH_344', 'killedBy', 'CH_344'),
#  (5, 8, 24, 'CH_272', 'killedBy', 'CH_345'),
#  (6, 9, 57, 'CH_314', 'killedBy', 'CH_345'),
#  (6, 1, 25, 'CH_11', 'killedBy', 'CH_348'),
#  (1, 1, 23, 'CH_293', 'sex', 'CH_349'),
#  (3, 8, 19, 'CH_300', 'married', 'CH_349'),
#  (1, 9, 14, 'CH_309', 'sex', 'CH_349'),
#  (1, 9, 16, 'CH_309', 'sex', 'CH_349'),
#  (1, 10, 19, 'CH_309', 'sex', 'CH_349'),
#  (2, 9, 5, 'CH_309', 'sex', 'CH_349'),
#  (3, 2, 36, 'CH_309', 'sex', 'CH_349'),
#  (4, 10, 38, 'CH_309', 'killedBy', 'CH_349'),
#  (4, 10, 40, 'CH_350', 'killedBy', 'CH_349'),
#  (1, 4, 8, 'CH_53', 'sex', 'CH_355'),
#  (4, 2, 6, 'CH_291', 'married', 'CH_356'),
#  (1, 1, 13, 'CH_68', 'killedBy', 'CH_362'),
#  (5, 8, 44, 'CH_170', 'killedBy', 'CH_362'),
#  (1, 1, 10, 'CH_360', 'killedBy', 'CH_362'),
#  (1, 1, 13, 'CH_68', 'killedBy', 'CH_363'),
#  (5, 8, 44, 'CH_170', 'killedBy', 'CH_363'),
#  (1, 1, 10, 'CH_360', 'killedBy', 'CH_363'),
#  (1, 1, 13, 'CH_68', 'killedBy', 'CH_364'),
#  (5, 8, 44, 'CH_170', 'killedBy', 'CH_364'),
#  (1, 1, 10, 'CH_360', 'killedBy', 'CH_364'),
#  (2, 10, 37, 'CH_53', 'sex', 'CH_375'),
#  (3, 5, 5, 'CH_123', 'sex', 'CH_378'),
#  (4, 9, 41, 'CH_262', 'killedBy', 'CH_378'),
#  (6, 3, 6, 'CH_71', 'killedBy', 'CH_386')]

# %% [markdown]
# <u>Python Code</u>

# %%
import json
import pandas as pd
with open('C:/Users/59482\Desktop/IntroToDB/HW1C/GoTHW/Data/json/episodes.json',encoding = "utf-8") as f:
    df = json.load(f)
df=df['episodes']

res = []
for item in df:
    scenes = item['scenes']
    for i in range(len(scenes)):
        scene = scenes[i]
        sceneNo = i + 1
        characters = scene['characters']
        for character in characters:
            if 'killedBy' in character or 'sex' in character or 'married' in character:
                obj = {}
                obj['seasonNum'] = item['seasonNum']
                obj['episodeNum'] = item['episodeNum']
                obj['sceneNo'] = sceneNo
                if 'killedBy' in character and character['killedBy']:
                    obj['name1'] = character['name']
                    obj['action'] = 'killedBy'
                    obj['name2'] = character['killedBy'][0]
                    obj['type'] = character['mannerOfDeath'] if 'mannerOfDeath' in characters else ' '

                elif 'sex' in character and character['sex']:
                    obj['name1'] = character['name']
                    obj['action'] = 'sex'
                    obj['name2'] = character['sex']['with'][0]
                    obj['type'] = character['sex']['type'][0]

                elif 'married' in character and character['married']:
                    obj['name1'] = character['name']
                    obj['action'] = 'married'
                    obj['name2'] = character['married']['to']
                    obj['type'] = character['married']['type']
                res.append(obj)

events = pd.DataFrame(res)
events.to_csv('events.csv')

# %% [markdown]
# ### Data Access Abstraction
#
# - A common API and abstraction for manipulating different database types and schema simplifies the development of web applications and other applications. There are many abstractions.
#
# | <img src="./Lecture_4_ER_SQL_Relational_GoT_9.jpg"> |
# | :---: |
# | __Data Access Objects__ |
#
# - The second programming tasks is to implement our own abstraction. This is RDBDataTable, which implements an abstraction we will use in subsequent homework assignments, and which we will use to enable our web application.
#
#
# - You can find the implementation template in the ```src``` directory of the project template.
#
#
# - For HW 1, Part C, you can copy your implementation code into this notebook and test again the cloud databases.
#
#
# - __I strongly suggest that you develop and test in PyCharm, and then copy your code into the notebook. The cells below just show you where to place your code. You should copy your code over from PyCharm.__

# %% [markdown]
# #### Implementation
#
# - ```BaseDataTable``` defines the common abstraction we will use. You do not need to do anything to this class.

# %%
# Import package to enable defining abstract classes in Python.
# Do not worry about understanding abstract base classes. This is just a class that defines
# some methods that subclasses must implement.
from abc import ABC, abstractmethod


class DataTableException(Exception):
    """
    A simple class that maps underlying implementation exceptions to generic exceptions.
    """

    invalid_method = 1001

    # General
    def __init__(self, code, message):
        self.code = code
        self.message = message

    def __str__(self):
        result = (
            type(self), {"code": self.code, "message": self.message}
        )
        result = str(result)
        return result


class BaseDataTable(ABC):
    """
    The implementation classes (XXXDataTable) for CSV database, relational, etc. will extend the
    base class and implement the abstract methods.
    """

    def __init__(self, entity_type_name, connect_info, key_columns=None, context=None):
        """

        :param entity_type_name: Name of the logcal entity type. This maps to various abstractions in
            underlying stores, e.g. file names, RDB tables, Neo4j Labels, ...
        :param connect_info: Dictionary of parameters necessary to connect to the data. See examples in subclasses.
        :param key_columns: List, in order, of the columns (fields) that comprise the primary key.
            A primary key is a set of columns whose values are unique and uniquely identify a row. For Appearances,
            the columns are ['playerID', 'teamID', 'yearID']
        :param contex: Holds context and environment information.
        """
        self._table_name = entity_type_name
        self._connect_info = connect_info
        self._key_columns = key_columns
        self._context = context

    @abstractmethod
    def find_by_primary_key(self, key_fields, field_list=None, context=None):
        """

        :param key_fields: The values for the key_columns, in order, to use to find a record. For example,
            for Appearances this could be ['willite01', 'BOS', '1960']
        :param field_list: A subset of the fields of the record to return. The CSV file or RDB table may have many
            additional columns, but the caller only requests this subset.
        :return: None, or a dictionary containing the columns/values for the row.
        """
        pass

    @abstractmethod
    def find_by_template(self, template, field_list=None, limit=None, offset=None, order_by=None, context=None):
        """

        :param template: A dictionary of the form { "field1" : value1, "field2": value2, ...}. The function will return
            a derived table containing the rows that match the template.
        :param field_list: A list of requested fields of the form, ['fielda', 'fieldb', ...]
        :param limit: Do not worry about this for now.
        :param offset: Do not worry about this for now.
        :param order_by: Do not worry about this for now.
        :return: A derived table containing the computed rows.
        """
        pass

    @abstractmethod
    def insert(self, new_entity, context=None):
        """

        :param new_record: A dictionary representing a row to add to the set of records. Raises an exception if this
            creates a duplicate primary key.
        :return: None
        """
        pass

    @abstractmethod
    def delete_by_template(self, template, context=None):
        """

        Deletes all records that match the template.

        :param template: A template.
        :return: A count of the rows deleted.
        """
        pass

    @abstractmethod
    def delete_by_key(self, key_fields, Context=None):
        """

        Delete record with corresponding key.

        :param key_fields: List containing the values for the key columns
        :return: A count of the rows deleted.
        """
        pass

    @abstractmethod
    def update_by_template(self, template, new_values, context=None):
        """

        :param template: A template that defines which matching rows to update.
        :param new_values: A dictionary containing fields and the values to set for the corresponding fields
            in the records. This returns an error if the update would create a duplicate primary key. NO ROWS are
            update on this error.
        :return: The number of rows updates.
        """
        pass

    @abstractmethod
    def update_by_key(self, key_fields, new_values, context=None):
        """

        :param key_fields: List of values for primary key fields
        :param new_values: A dictionary containing fields and the values to set for the corresponding fields
            in the records. This returns an error if the update would create a duplicate primary key. NO ROWS are
            update on this error.
        :return: The number of rows updates.
        """
        pass

    @abstractmethod
    def query(self, query_statement, args, context=None):
        """
        Passed through/executes a raw query in the native implementation language of the backend.
        :param query_statement: Query statement as a string.
        :param args: Args to insert into query if it is a template
        :param context:
        :return: A JSON object containing the result of the operation.
        """
        pass

    @abstractmethod
    def load(self, rows=None):
        """
        Loads data into the data table.
        :param rows:
        :return: Number of rows loaded.
        """

    @abstractmethod
    def save(self, context):
        """
        Writes any cached data to a backing store.
        :param context:
        :return:
        """

# %% [markdown]
# __RDBDataTable__
#
#
# - You only need to implement the following methods:
#     - ```__init__```
#     - ```__str__```
#     - ```find_by_template``` You only need to implement the parameters
#         - ```template```
#         - ```field_list```
#     - ```find_by_primary_key``` You only need to implement the parameters
#         - ```key_fields```
#         - ```field_list```
#
#
# - The logical behavior of the ```find_by_template``` API is the following:
#     - If you create an ```RDBDataTable``` instance for a SQL table ```GoTSolutionClean.scenes_characters,```
#     - The call<br>
# ```
#     characters_tbl.find_by_template(
#             template={
#                 'seasonNum': 1,
#                 'episodeNum': 2
#                 },
#             field_list = ['seasonNum', 'episodeNum', 'sceneNo', 'character_id']
#             )
# ```
#     - Is equivalent to
# ```
#     select seasonNum, episodeNum, sceneNo, character_id
#         from GoTSolutionClean.scenes_characters
#         where
#             seasonNum=1 and episodeNum=1
# ```
#     - And returns the same dictionary.

# %% [markdown]
# - The logical behavior of the ```find_by_primary_key``` API is the following:
#     - If you create an ```RDBDataTable``` instance for a SQL table ```GoTSolutionClean.episodes,```
#     - The primary key columns are ```seasonNum, episodeNum.```
#     - The invocation would be ```find_by_primary_key([1,3],field_list=['seasonNum','episodeNum','title'])```
#     - This would get converted into
# ```
# select seasonNum, episodeNum, title
#         from W4111GoTSolutionClean.episodes
#         where
#             seasonNum=1 and episodeNum=1
# ```
#     - Your class implementation MUST run a database query to determine the primary key columns and their order to form the ```where``` clause.
#     - The result is a single dictionary containing the query result.
#
#
# - We will provide tests.

# %%
from src.data_tables.BaseDataTable import BaseDataTable

import pandas as pd
import pymysql

import logging

logger = logging.getLogger()


class RDBDataTable(BaseDataTable):
    """
    RDBDataTable is relation DB implementation of the BaseDataTable.
    """

    # Default connection information in case the code does not pass an object
    # specific connection on object creation.
    _default_connect_info = {
        'host':"localhost",
        'user':"root",
        'password':"Djxwxydy4016739",
        'db':"W4111GoTSolution",
        'port': 3306
    }

    _default_cnx = None

    def _get_cnx(self):

        if self._cnx is None:
            if self._connect_info is None:
                c_info = RDBDataTable._default_connect_info
            else:
                c_info = self._connect_info

            self._cnx = pymysql.connect(
                host=c_info['host'],
                user=c_info['user'],
                password=c_info['password'],
                db=c_info['db'],
                charset='utf8mb4',
                cursorclass=pymysql.cursors.DictCursor)

        return self._cnx

    def __init__(self, table_name, key_columns=None, connect_info=None):
        """

        :param table_name: The name of the RDB table.
        :param connect_info: Dictionary of parameters necessary to connect to the data.
        :param key_columns: List, in order, of the columns (fields) that comprise the primary key.
            This is for compatibility with other types of data table. Any value other than None is an error.
        """

        # If there is not explicit connect information, use the defaults.



        if key_columns is not None:
            raise ValueError("This is an RDB Data Table. We figure out the keys by querying the DB.")

        ####### Your Code Goes Here #########
        self._cnx=None
        self._connect_info=None
        self._table_name = table_name
        self.key_columns = key_columns
        self._connect_info=connect_info
        ####### Your Code Goes Here #########
    def get_row_count(self):
        sql="select count(*) as count from "+ self._table_name
        res=self._run_q(sql,fetch =True)
        return res[0]['count']

    def get_key_columns(self):
        sql = 'show keys from ' + self._table_name+ " WHERE Key_name = 'PRIMARY'"
        res = self._run_q(sql, fetch=True)
        result=[]
        for re in res:
            re=str(re['Column_name'])
            result.append(re)
        return result

    def get_columns(self):
        sql='describe '+ self._table_name
        res=self._run_q(sql,fetch=True)
        result=[]
        for re in res:
            result.append(re['Field'])
        return result
    

    def __str__(self):
        """

        :return: String representation of the table's metadata.
        """
        ####### Your Code Goes Here #########
        result = 'RDBDataTable '+ self._table_name
        result += '\n\tRow Count='+ str(self.get_row_count())
        result+= '\n\t Key=' + str(self.get_key_columns())
        result+= '\n\tColumns='+str(self.get_columns())
        return result
        ####### Your Code Goes Here #########

    def _run_q(self, q, args=None, fields=None, fetch=True, cnx=None, cursor=None, commit=True):
        """

        :param q: An SQL query string that may have %s slots for argument insertion. The string
            may also have {} after select for columns to choose.
        :param args: A tuple of values to insert in the %s slots.
        :param fetch: If true, return the result.
        :param cnx: A database connection. May be None
        :param cncursor: Do not worry about this for now.
        :param commit: Do not worry about this for now. This is more wizard stuff.
        :return: A result set or None.
        """

        r = None

        cursor_created = False

        if cnx is None:
            cnx = self._get_cnx()

        try:
            # Use the connection in the object if no connection provided.

            # Convert the list of columns into the form "col1, col2, ..." for following SELECT.
            if fields:
                q = q.format(",".join(fields))
            else:
                q = q.format('*')

            if cursor is None:
                cursor = cnx.cursor()  # Just ignore this for now.
                cursor_created = True

            # If debugging is turned on, will print the query sent to the database.
            #self.debug_message("Query = ", cursor.mogrify(q, args))

            cursor.execute(q, args)  # Execute the query.

            # Technically, INSERT, UPDATE and DELETE do not return results.
            # Sometimes the connector libraries return the number of created/deleted rows.
            if fetch:
                r = cursor.fetchall()  # Return all elements of the result.
            else:
                r = None

            if commit:                  # Do not worry about this for now.
                cnx.commit()

            if cursor_created:
                cursor.close()

        except Exception as e:
            print("Exception e = ", e)
            if commit:
                cnx.rollback()
            if cursor_created:
                cursor.close()

        return r

    def _run_insert(self, table_name, column_list, values_list, cnx=None, commit=True):
        """

        :param table_name: Name of the table to insert data. Probably should just get from the object data.
        :param column_list: List of columns for insert.
        :param values_list: List of column values.
        :param cnx: Ignore this for now.
        :param commit: Ignore this for now.
        :return:
        """
        try:
            q = "insert into " + table_name + " "

            # If the column list is not None, form the (col1, col2, ...) part of the statement.
            if column_list is not None:
                q += "(" + ",".join(column_list) + ") "

            # We will use query parameters. For a term of the form values(%s, %s, ...) with one slot for
            # each value to insert.
            values = ["%s"] * len(values_list)

            # Form the values(%s, %s, ...) part of the statement.
            values = " ( " + ",".join(values) + ") "
            values = "values" + values

            # Put all together.
            q += values

            self._run_q(q, args=values_list, fields=None, fetch=False, cnx=cnx, commit=commit)

        except Exception as e:
            print("Got exception = ", e)
            raise e

    def get_folders(self):
        pass

    def find_by_primary_key(self, key_fields, field_list=None, context=None):
        """

        :param key_fields: The values for the key_columns, in order, to use to find a record.
        :param field_list: A subset of the fields of the record to return.
        :return: None, or a dictionary containing the request fields for the record identified
            by the key.
        """
        pass
        ####### Your Code Goes Here #########
        dict_key_col={}
        for i in range(len(self.get_key_columns())):
            dict_key_col[self.get_key_columns()[i]]=key_fields[i]
        where_result=[]
        for key, value in dict_key_col.items():
            col_con=str(key)+' = '+str(value)
            where_result.append(col_con)
        if len(where_result)>2:
            where_final_result=(' and ').join(where_result)
        else:
            where_final_result= str(where_result[0])
        if len(field_list)>2:
            select_column = (', ').join(field_list)
        else:
            select_column=str(field_list[0])
        sql = "select " + select_column + ' from ' + self._table_name + '  where ' + where_final_result
        result = self._run_q(sql, fetch=True)
        return result
        ####### Your Code Goes Here #########

    def _template_to_where_clause(self, t):
        """
        Convert a query template into a WHERE clause.
        :param t: Query template.
        :return: (WHERE clause, arg values for %s in clause)
        """
        w_clause = None
        args = None

        ####### Your Code Goes Here #########
        pass

        ####### Your Code Goes Here #########

        return w_clause, args

    def find_by_template(self, template, field_list=None, limit=None, offset=None, order_by=None, commit=True,
                         context=None):
        """

        :param template: A dictionary of the form { "field1" : value1, "field2": value2, ...}
        :param field_list: A list of request fields of the form, ['fielda', 'fieldb', ...]
        :param limit: Do not worry about this for now.
        :param offset: Do not worry about this for now.
        :param order_by: Do not worry about this for now.
        :return: A list containing dictionaries. A dictionary is in the list representing each record
            that matches the template. The dictionary only contains the requested fields.
        """
        ####### Your Code Goes Here #########
        where_res=[]
        for key, value in template.items():
            col_con=str(key)+' = '+str(value)
            where_result.append(col_con)
        if len(where_result)>2:
            where_final_result=(' and ').join(where_result)
        else:
            where_final_result= str(where_result[0])
        if len(field_list)>2:
            select_column = (', ').join(field_list)
        else:
            select_column=str(field_list[0])
        sql = "select " + select_column + ' from ' + self._table_name + '  where ' + where_final_result
        result = self._run_q(sql, fetch=True)
        return result

        ####### Your Code Goes Here #########

    def insert(self, new_record, context=None):
        """

        :param new_record: A dictionary representing a row to add to the set of records.
        :return: None
        """
        pass

    def delete_by_template(self, template, context=None):
        """

        Deletes all records that match the template.

        :param template: A template.
        :return: A count of the rows deleted.
        """
        pass

    def delete_by_key(self, key_fields, context=None):
        """

        Delete record with corresponding key.

        :param key_fields: List containing the values for the key columns
        :return: A count of the rows deleted.
        """
        pass

    def update_by_template(self, template, new_values, context=None):
        """

        :param template: A template that defines which matching rows to update.
        :param new_values: A dictionary containing fields and the values to set for the corresponding fields
            in the records. This returns an error if the update would create a duplicate primary key. NO ROWS are
            update on this error.
        :return: The number of rows updates.
        """
        pass

    def update_by_key(self, key_fields, new_values, context=None):
        """

        :param key_fields: List of values for primary key fields
        :param new_values: A dictionary containing fields and the values to set for the corresponding fields
            in the records. This returns an error if the update would create a duplicate primary key. NO ROWS are
            update on this error.
        :return: The number of rows updates.
        """
        pass

    def load(self, rows=None):
        pass

    def save(self, context=None):
        pass

    def query(self, query_statement, args, context=None):
        pass

# %% [markdown]
# __Tests__
#
# - We will provide some tests.

# %%
#from src.data_tables.RDBDataTable import RDBDataTable
import src.data_tables.RDBDataTable
import imp
imp.reload(src.data_tables.RDBDataTable) 
from src.data_tables.RDBDataTable import RDBDataTable
import json
def t1():

    print("\n************** t1 **************\n")

    t = RDBDataTable("W4111GoTSolution.scenes")
    print("Table = ", t)
    print("\n")


def t2():

    print("\n************** t2 **************\n")

    t = RDBDataTable("W4111GoTSolution.episodes")

    res = t.find_by_template(
        {"seasonNum": 1},
        field_list=['seasonNum', 'episodeNum', 'episodeTitle']
    )

    print("Answer = ")
    print(json.dumps(res, indent=2, default=str))

    print("\n************** t2 **************\n")


def t3():


    print("\n************** t3 **************\n")

    t = RDBDataTable("W4111GoTSolution.scenes")

    res = t.find_by_primary_key([3,1, 11],
        field_list=['seasonNum', 'episodeNum', 'sceneNo', "location", "subLocation"]
    )

    print("Answer = \n")
    print(json.dumps(res, indent=2, default=str))


    print("\n************** t3 **************\n")



def t4():

    print("\n************** t4 **************\n")

    t = RDBDataTable("W4111GoTSolution.scenes")

    k = t.get_key_columns()
    print("Key columns = ", k)

    print("\n************** t4 **************\n")

# %%
t1()
# Out:
# ************** t1 **************
#
# Table =  RDBDataTable W4111GoTSolution.scenes
# 	Row Count=3824
# 	 Key=['seasonNum', 'episodeNum', 'sceneNo']
# 	Columns=['id', 'seasonNum', 'episodeNum', 'sceneNo', 'sceneStart', 'sceneEnd', 'location', 'subLocation', 'greensight', 'altLocation', 'warg', 'flashback']

# %%
t2()
# Out:
# ************** t2 **************
#
# Answer =
# [
#   {
#     "seasonNum": 1,
#     "episodeNum": 1,
#     "episodeTitle": "Winter Is Coming"
#   },
#   {
#     "seasonNum": 1,
#     "episodeNum": 2,
#     "episodeTitle": "The Kingsroad"
#   },
#   {
#     "seasonNum": 1,
#     "episodeNum": 3,
#     "episodeTitle": "Lord Snow"
#   },
#   {
#     "seasonNum": 1,
#     "episodeNum": 4,
#     "episodeTitle": "Cripples, Bastards, and Broken Things"
#   },
#   {
#     "seasonNum": 1,
#     "episodeNum": 5,
#     "episodeTitle": "The Wolf and the Lion"
#   },
#   {
#     "seasonNum": 1,
#     "episodeNum": 6,
#     "episodeTitle": "A Golden Crown"
#   },
#   {
#     "seasonNum": 1,
#     "episodeNum": 7,
#     "episodeTitle": "You Win or You Die"
#   },
#   {
#     "seasonNum": 1,
#     "episodeNum": 8,
#     "episodeTitle": "The Pointy End"
#   },
#   {
#     "seasonNum": 1,
#     "episodeNum": 9,
#     "episodeTitle": "Baelor"
#   },
#   {
#     "seasonNum": 1,
#     "episodeNum": 10,
#     "episodeTitle": "Fire and Blood"
#   }
# ]
#
# ************** t2 **************

# %%
t3()
# Out:
# ************** t3 **************
#
# Answer =
#
# [
#   {
#     "seasonNum": 3,
#     "episodeNum": 1,
#     "sceneNo": 11,
#     "location": "North of the Wall",
#     "subLocation": "Frostfang Mountains"
#   }
# ]
#
# ************** t3 **************

# %%
t4()
# Out:
# ************** t4 **************
#
# Key columns =  ['seasonNum', 'episodeNum', 'sceneNo']
#
# ************** t4 **************
